# %%
# ondoing main libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# import jupyterthemes as jt
# from jupyterthemes import jtplot
# !jt -t onedork -ofs 10 -dfs 9 -nfs 11 -tfs 11
# jtplot.style(theme = 'onedork', fscale = 1.4 , context = 'notebook', ticks = True, 
#              grid = False)

# %%
# !jt -r
# Out:
# Reset css and font defaults in:
# /home/tater/.jupyter/custom &
# /home/tater/.local/share/jupyter/nbextensions

# %%
# hiding possible warning in the system
import warnings
warnings.filterwarnings('ignore')

# %%
df_1 = pd.read_csv("Cryofreezer_all_variables_29.csv", delimiter=',')
df_2 = pd.read_csv("Cryofreezer_all_variables_30.csv", delimiter=',')
df_3 = pd.read_csv("Cryofreezer_all_variables_31.csv", delimiter=',')
df_4 = pd.read_csv("Cryofreezer_all_variables_32.csv", delimiter=',')
df_5 = pd.read_csv("Cryofreezer_all_variables_33.csv", delimiter=',')

# %%
# entering a deltatime between to moments of experiments
def deltatime(dataframe):
    begin = dataframe[0]
    for i in range(len(dataframe)):   
        cur = dataframe[i]
        delta = cur - begin
        dataframe[i] = delta.seconds

# %%
#file concatanation
df_all = df_1
df_all
# Out:
#       BeltAmpere_belt1  BeltAmpere_belt1_qc  BeltAmpere_belt2  \
# 0             0.002441                    0          0.002441
# 1             0.000000          -2138963968          0.000000
# 2             0.000000          -2138963968          0.000000
# 3             0.002441                    0          0.002441
# 4             0.000000          -2138963968          0.000000
# ...                ...                  ...               ...
# 7995          0.000000          -2138963968          0.000000
# 7996          2.424927                    0          3.586426
# 7997          0.000000          -2138963968          0.000000
# 7998          2.425537                    0          3.657837
# 7999          2.429199                    0          3.630371
#
#       BeltAmpere_belt2_qc  BeltAmpere_belt3  BeltAmpere_belt3_qc  \
# 0                       0          0.002441                    0
# 1             -2138963968          0.000000          -2138963968
# 2             -2138963968          0.000000          -2138963968
# 3                       0          0.002441                    0
# 4             -2138963968          0.000000          -2138963968
# ...                   ...               ...                  ...
# 7995          -2138963968          0.000000          -2138963968
# 7996                    0          3.527832                    0
# 7997          -2138963968          0.000000          -2138963968
# 7998                    0          3.540039                    0
# 7999                    0          3.510132                    0
#
#       Cumulative_LIN_flow  Cumulative_LIN_flow_qc  Cumulative_product_flow  \
# 0                  317404                       0                   158249
# 1                       0             -2138963968                        0
# 2                       0             -2138963968                        0
# 3                  317404                       0                   158249
# 4                       0             -2138963968                        0
# ...                   ...                     ...                      ...
# 7995                    0             -2138963968                        0
# 7996               348959                       0                   175974
# 7997                    0             -2138963968                        0
# 7998               348988                       0                   175995
# 7999               349003                       0                   176005
#
#       Cumulative_product_flow_qc  ...  Temp_product_in_qc  Temp_product_out  \
# 0                              0  ...                   0          0.000000
# 1                    -2138963968  ...         -2138963968          0.000000
# 2                    -2138963968  ...         -2138963968          0.000000
# 3                              0  ...                   0          7.590608
# 4                    -2138963968  ...         -2138963968          0.000000
# ...                          ...  ...                 ...               ...
# 7995                 -2138963968  ...         -2138963968          0.000000
# 7996                           0  ...                   0        -21.489439
# 7997                 -2138963968  ...         -2138963968          0.000000
# 7998                           0  ...                   0        -23.823202
# 7999                           0  ...                   0        -24.292710
#
#       Temp_product_out_qc  Temp_tunnel_measured  Temp_tunnel_measured_qc  \
# 0                       0                  16.9                        0
# 1             -2138963968                   0.0              -2138963968
# 2             -2138963968                   0.0              -2138963968
# 3                       0                  15.0                        0
# 4             -2138963968                   0.0              -2138963968
# ...                   ...                   ...                      ...
# 7995          -2138963968                   0.0              -2138963968
# 7996                    0                 -85.9                        0
# 7997          -2138963968                   0.0              -2138963968
# 7998                    0                 -85.9                        0
# 7999                    0                 -85.9                        0
#
#       Temp_tunnel_set  Temp_tunnel_set_qc  Vanne_opening_rate  \
# 0                   0                   0            0.000000
# 1                   0         -2138963968            0.000000
# 2                   0         -2138963968            0.000000
# 3                   0                   0            0.000000
# 4                   0         -2138963968            0.000000
# ...               ...                 ...                 ...
# 7995                0         -2138963968            0.000000
# 7996              -86                   0           25.934847
# 7997                0         -2138963968            0.000000
# 7998              -86                   0           24.692324
# 7999              -86                   0           25.277805
#
#       Vanne_opening_rate_qc                     _time
# 0                         0  2020-09-04T20:56:07.400Z
# 1               -2138963968  2020-09-04T20:57:07.338Z
# 2               -2138963968  2020-09-04T20:58:28.422Z
# 3                         0  2020-09-04T20:59:07.374Z
# 4               -2138963968  2020-09-04T21:00:28.093Z
# ...                     ...                       ...
# 7995            -2138963968  2020-09-10T10:11:48.233Z
# 7996                      0  2020-09-10T10:12:48.266Z
# 7997            -2138963968  2020-09-10T10:13:48.240Z
# 7998                      0  2020-09-10T10:14:48.312Z
# 7999                      0  2020-09-10T10:15:48.283Z
#
# [8000 rows x 51 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 51 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   BeltAmpere_belt1            8000 non-null   float64
#  1   BeltAmpere_belt1_qc         8000 non-null   int64
#  2   BeltAmpere_belt2            8000 non-null   float64
#  3   BeltAmpere_belt2_qc         8000 non-null   int64
#  4   BeltAmpere_belt3            8000 non-null   float64
#  5   BeltAmpere_belt3_qc         8000 non-null   int64
#  6   Cumulative_LIN_flow         8000 non-null   int64
#  7   Cumulative_LIN_flow_qc      8000 non-null   int64
#  8   Cumulative_product_flow     8000 non-null   int64
#  9   Cumulative_product_flow_qc  8000 non-null   int64
#  10  FanAmpere_exhaust1          8000 non-null   float64
#  11  FanAmpere_exhaust1_qc       8000 non-null   int64
#  12  FanAmpere_exhaust2          8000 non-null   float64
#  13  FanAmpere_exhaust2_qc       8000 non-null   int64
#  14  FanAmpere_side              8000 non-null   float64
#  15  FanAmpere_side_qc           8000 non-null   int64
#  16  FanAmpere_top               8000 non-null   float64
#  17  FanAmpere_top_qc            8000 non-null   int64
#  18  Fanspeed_exhaust1           8000 non-null   int64
#  19  Fanspeed_exhaust1_qc        8000 non-null   int64
#  20  Fanspeed_exhaust2           8000 non-null   int64
#  21  Fanspeed_exhaust2_qc        8000 non-null   int64
#  22  Fanspeed_side               8000 non-null   int64
#  23  Fanspeed_side_qc            8000 non-null   int64
#  24  Fanspeed_top                8000 non-null   int64
#  25  Fanspeed_top_qc             8000 non-null   int64
#  26  LIN_flow                    8000 non-null   float64
#  27  LIN_flow_qc                 8000 non-null   int64
#  28  Product_flow                8000 non-null   float64
#  29  Product_flow_qc             8000 non-null   int64
#  30  ResidenceTime_belt1         8000 non-null   int64
#  31  ResidenceTime_belt1_qc      8000 non-null   int64
#  32  ResidenceTime_belt2         8000 non-null   int64
#  33  ResidenceTime_belt2_qc      8000 non-null   int64
#  34  ResidenceTime_belt3         8000 non-null   int64
#  35  ResidenceTime_belt3_qc      8000 non-null   int64
#  36  Temp_exhaust_in             8000 non-null   float64
#  37  Temp_exhaust_in_qc          8000 non-null   int64
#  38  Temp_exhaust_out            8000 non-null   float64
#  39  Temp_exhaust_out_qc         8000 non-null   int64
#  40  Temp_product_in             8000 non-null   float64
#  41  Temp_product_in_qc          8000 non-null   int64
#  42  Temp_product_out            8000 non-null   float64
#  43  Temp_product_out_qc         8000 non-null   int64
#  44  Temp_tunnel_measured        8000 non-null   float64
#  45  Temp_tunnel_measured_qc     8000 non-null   int64
#  46  Temp_tunnel_set             8000 non-null   int64
#  47  Temp_tunnel_set_qc          8000 non-null   int64
#  48  Vanne_opening_rate          8000 non-null   float64
#  49  Vanne_opening_rate_qc       8000 non-null   int64
#  50  _time                       8000 non-null   object
# dtypes: float64(15), int64(35), object(1)
# memory usage: 3.1+ MB

# %%
df_all_short = df_all.iloc[:, ::2]
df_all_short
# Out:
#       BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# 0             0.002441          0.002441          0.002441
# 1             0.000000          0.000000          0.000000
# 2             0.000000          0.000000          0.000000
# 3             0.002441          0.002441          0.002441
# 4             0.000000          0.000000          0.000000
# ...                ...               ...               ...
# 7995          0.000000          0.000000          0.000000
# 7996          2.424927          3.586426          3.527832
# 7997          0.000000          0.000000          0.000000
# 7998          2.425537          3.657837          3.540039
# 7999          2.429199          3.630371          3.510132
#
#       Cumulative_LIN_flow  Cumulative_product_flow  FanAmpere_exhaust1  \
# 0                  317404                   158249            0.002182
# 1                       0                        0            0.000000
# 2                       0                        0            0.000000
# 3                  317404                   158249            0.002182
# 4                       0                        0            0.000000
# ...                   ...                      ...                 ...
# 7995                    0                        0            0.000000
# 7996               348959                   175974            2.144040
# 7997                    0                        0            0.000000
# 7998               348988                   175995            2.141422
# 7999               349003                   176005            2.142731
#
#       FanAmpere_exhaust2  FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# 0               0.002618        0.000000       0.000000                  0
# 1               0.000000        0.000000       0.000000                  0
# 2               0.000000        0.000000       0.000000                  0
# 3               0.002618        0.000000       0.000000                  0
# 4               0.000000        0.000000       0.000000                  0
# ...                  ...             ...            ...                ...
# 7995            0.000000        0.000000       0.000000                  0
# 7996            2.456940        8.002167       8.134003                 50
# 7997            0.000000        0.000000       0.000000                  0
# 7998            2.458249        8.002167       8.129883                 50
# 7999            2.456067        8.003540       8.140869                 50
#
#       ...  ResidenceTime_belt2  ResidenceTime_belt3  Temp_exhaust_in  \
# 0     ...                    0                    0             17.1
# 1     ...                    0                    0              0.0
# 2     ...                    0                    0              0.0
# 3     ...                    0                    0             16.7
# 4     ...                    0                    0              0.0
# ...   ...                  ...                  ...              ...
# 7995  ...                    0                    0              0.0
# 7996  ...                  150                  150             -1.7
# 7997  ...                    0                    0              0.0
# 7998  ...                  150                  150             -1.3
# 7999  ...                  150                  150             -1.9
#
#       Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# 0                 14.3        10.357108          0.000000
# 1                  0.0         0.000000          0.000000
# 2                  0.0         0.000000          0.000000
# 3                 13.8        12.060572          7.590608
# 4                  0.0         0.000000          0.000000
# ...                ...              ...               ...
# 7995               0.0         0.000000          0.000000
# 7996               4.4        12.040358        -21.489439
# 7997               0.0         0.000000          0.000000
# 7998               4.8        12.768709        -23.823202
# 7999               4.6        13.013583        -24.292710
#
#       Temp_tunnel_measured  Temp_tunnel_set  Vanne_opening_rate  \
# 0                     16.9                0            0.000000
# 1                      0.0                0            0.000000
# 2                      0.0                0            0.000000
# 3                     15.0                0            0.000000
# 4                      0.0                0            0.000000
# ...                    ...              ...                 ...
# 7995                   0.0                0            0.000000
# 7996                 -85.9              -86           25.934847
# 7997                   0.0                0            0.000000
# 7998                 -85.9              -86           24.692324
# 7999                 -85.9              -86           25.277805
#
#                          _time
# 0     2020-09-04T20:56:07.400Z
# 1     2020-09-04T20:57:07.338Z
# 2     2020-09-04T20:58:28.422Z
# 3     2020-09-04T20:59:07.374Z
# 4     2020-09-04T21:00:28.093Z
# ...                        ...
# 7995  2020-09-10T10:11:48.233Z
# 7996  2020-09-10T10:12:48.266Z
# 7997  2020-09-10T10:13:48.240Z
# 7998  2020-09-10T10:14:48.312Z
# 7999  2020-09-10T10:15:48.283Z
#
# [8000 rows x 26 columns]

# %%
df_all_short["_time"] = pd.to_datetime(df_all_short["_time"])

# %%
df_all_short
# Out:
#       BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# 0             0.002441          0.002441          0.002441
# 1             0.000000          0.000000          0.000000
# 2             0.000000          0.000000          0.000000
# 3             0.002441          0.002441          0.002441
# 4             0.000000          0.000000          0.000000
# ...                ...               ...               ...
# 7995          0.000000          0.000000          0.000000
# 7996          2.424927          3.586426          3.527832
# 7997          0.000000          0.000000          0.000000
# 7998          2.425537          3.657837          3.540039
# 7999          2.429199          3.630371          3.510132
#
#       Cumulative_LIN_flow  Cumulative_product_flow  FanAmpere_exhaust1  \
# 0                  317404                   158249            0.002182
# 1                       0                        0            0.000000
# 2                       0                        0            0.000000
# 3                  317404                   158249            0.002182
# 4                       0                        0            0.000000
# ...                   ...                      ...                 ...
# 7995                    0                        0            0.000000
# 7996               348959                   175974            2.144040
# 7997                    0                        0            0.000000
# 7998               348988                   175995            2.141422
# 7999               349003                   176005            2.142731
#
#       FanAmpere_exhaust2  FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# 0               0.002618        0.000000       0.000000                  0
# 1               0.000000        0.000000       0.000000                  0
# 2               0.000000        0.000000       0.000000                  0
# 3               0.002618        0.000000       0.000000                  0
# 4               0.000000        0.000000       0.000000                  0
# ...                  ...             ...            ...                ...
# 7995            0.000000        0.000000       0.000000                  0
# 7996            2.456940        8.002167       8.134003                 50
# 7997            0.000000        0.000000       0.000000                  0
# 7998            2.458249        8.002167       8.129883                 50
# 7999            2.456067        8.003540       8.140869                 50
#
#       ...  ResidenceTime_belt2  ResidenceTime_belt3  Temp_exhaust_in  \
# 0     ...                    0                    0             17.1
# 1     ...                    0                    0              0.0
# 2     ...                    0                    0              0.0
# 3     ...                    0                    0             16.7
# 4     ...                    0                    0              0.0
# ...   ...                  ...                  ...              ...
# 7995  ...                    0                    0              0.0
# 7996  ...                  150                  150             -1.7
# 7997  ...                    0                    0              0.0
# 7998  ...                  150                  150             -1.3
# 7999  ...                  150                  150             -1.9
#
#       Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# 0                 14.3        10.357108          0.000000
# 1                  0.0         0.000000          0.000000
# 2                  0.0         0.000000          0.000000
# 3                 13.8        12.060572          7.590608
# 4                  0.0         0.000000          0.000000
# ...                ...              ...               ...
# 7995               0.0         0.000000          0.000000
# 7996               4.4        12.040358        -21.489439
# 7997               0.0         0.000000          0.000000
# 7998               4.8        12.768709        -23.823202
# 7999               4.6        13.013583        -24.292710
#
#       Temp_tunnel_measured  Temp_tunnel_set  Vanne_opening_rate  \
# 0                     16.9                0            0.000000
# 1                      0.0                0            0.000000
# 2                      0.0                0            0.000000
# 3                     15.0                0            0.000000
# 4                      0.0                0            0.000000
# ...                    ...              ...                 ...
# 7995                   0.0                0            0.000000
# 7996                 -85.9              -86           25.934847
# 7997                   0.0                0            0.000000
# 7998                 -85.9              -86           24.692324
# 7999                 -85.9              -86           25.277805
#
#                                 _time
# 0    2020-09-04 20:56:07.400000+00:00
# 1    2020-09-04 20:57:07.338000+00:00
# 2    2020-09-04 20:58:28.422000+00:00
# 3    2020-09-04 20:59:07.374000+00:00
# 4    2020-09-04 21:00:28.093000+00:00
# ...                               ...
# 7995 2020-09-10 10:11:48.233000+00:00
# 7996 2020-09-10 10:12:48.266000+00:00
# 7997 2020-09-10 10:13:48.240000+00:00
# 7998 2020-09-10 10:14:48.312000+00:00
# 7999 2020-09-10 10:15:48.283000+00:00
#
# [8000 rows x 26 columns]

# %%
df_all_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   BeltAmpere_belt1         8000 non-null   float64
#  1   BeltAmpere_belt2         8000 non-null   float64
#  2   BeltAmpere_belt3         8000 non-null   float64
#  3   Cumulative_LIN_flow      8000 non-null   int64
#  4   Cumulative_product_flow  8000 non-null   int64
#  5   FanAmpere_exhaust1       8000 non-null   float64
#  6   FanAmpere_exhaust2       8000 non-null   float64
#  7   FanAmpere_side           8000 non-null   float64
#  8   FanAmpere_top            8000 non-null   float64
#  9   Fanspeed_exhaust1        8000 non-null   int64
#  10  Fanspeed_exhaust2        8000 non-null   int64
#  11  Fanspeed_side            8000 non-null   int64
#  12  Fanspeed_top             8000 non-null   int64
#  13  LIN_flow                 8000 non-null   float64
#  14  Product_flow             8000 non-null   float64
#  15  ResidenceTime_belt1      8000 non-null   int64
#  16  ResidenceTime_belt2      8000 non-null   int64
#  17  ResidenceTime_belt3      8000 non-null   int64
#  18  Temp_exhaust_in          8000 non-null   float64
#  19  Temp_exhaust_out         8000 non-null   float64
#  20  Temp_product_in          8000 non-null   float64
#  21  Temp_product_out         8000 non-null   float64
#  22  Temp_tunnel_measured     8000 non-null   float64
#  23  Temp_tunnel_set          8000 non-null   int64
#  24  Vanne_opening_rate       8000 non-null   float64
#  25  _time                    8000 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(15), int64(10)
# memory usage: 1.6 MB

# %%
x_time = df_all_short["_time"]
y_LIN = df_all_short["LIN_flow"]
y_PROD = df_all_short["Product_flow"]

# %%
plt.figure(figsize=(35, 35))
ax = plt.subplot(3,3,3)
plt.plot(x_time, y_LIN, color="red", label="LIN_flow")
plt.plot(x_time, y_PROD, color="black", label="Product_flow", alpha=0.5)
plt.xlabel("Time")
plt.ylabel("LIN_flow")
plt.grid(True)
plt.legend()

# %%
df_w_o_prod_flow = df_all_short[df_all_short["Product_flow"] >= 1.175381e-33]

# %%
df_w_o_prod_flow = df_w_o_prod_flow[df_all_short["Product_flow"] != 0]

# %%
df_w_o_prod_flow.shape
# Out:
# (874, 26)

# %%
df_w_o_prod_flow.reset_index(inplace=True, drop=True)

# %%
df_w_o_prod_flow
# Out:
#      BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# 0            1.570435          1.475830          1.376343
# 1            1.569214          1.478882          1.375732
# 2            1.570435          1.483154          1.378784
# 3            1.571045          1.483765          1.379395
# 4            1.569824          1.484985          1.382446
# ..                ...               ...               ...
# 869          2.423096          3.612061          3.531494
# 870          2.424316          3.628540          3.525391
# 871          2.424927          3.586426          3.527832
# 872          2.425537          3.657837          3.540039
# 873          2.429199          3.630371          3.510132
#
#      Cumulative_LIN_flow  Cumulative_product_flow  FanAmpere_exhaust1  \
# 0                 317404                   158249            3.082739
# 1                 317404                   158249            3.013788
# 2                 317404                   158249            3.031244
# 3                 317407                   158249            3.035608
# 4                 317410                   158249            3.017715
# ..                   ...                      ...                 ...
# 869               348917                   175943            2.134876
# 870               348930                   175953            2.142731
# 871               348959                   175974            2.144040
# 872               348988                   175995            2.141422
# 873               349003                   176005            2.142731
#
#      FanAmpere_exhaust2  FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# 0              3.447571        8.164215       8.456726                100
# 1              3.401749        8.146362       8.444366                100
# 2              3.449317        8.101044       8.422394                100
# 3              3.482919        8.121643       8.415527                100
# 4              3.401312        8.095551       8.432007                100
# ..                  ...             ...            ...                ...
# 869            2.453012        8.013153       8.144989                 50
# 870            2.453885        7.998047       8.136749                 50
# 871            2.456940        8.002167       8.134003                 50
# 872            2.458249        8.002167       8.129883                 50
# 873            2.456067        8.003540       8.140869                 50
#
#      ...  ResidenceTime_belt2  ResidenceTime_belt3  Temp_exhaust_in  \
# 0    ...                   60                   60             13.0
# 1    ...                   60                   60             12.4
# 2    ...                   60                   60             12.3
# 3    ...                   60                   60             12.1
# 4    ...                   60                   60             11.8
# ..   ...                  ...                  ...              ...
# 869  ...                  150                  150             -2.1
# 870  ...                  150                  150             -1.7
# 871  ...                  150                  150             -1.7
# 872  ...                  150                  150             -1.3
# 873  ...                  150                  150             -1.9
#
#      Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# 0                12.5         0.000000          0.000000
# 1                11.1         0.000000          0.000000
# 2                10.9         0.000000          0.000000
# 3                10.9         0.000000          0.000000
# 4                11.1         0.000000          0.000000
# ..                ...              ...               ...
# 869               4.7        10.797113          0.000000
# 870               4.7        11.044087        -16.853040
# 871               4.4        12.040358        -21.489439
# 872               4.8        12.768709        -23.823202
# 873               4.6        13.013583        -24.292710
#
#      Temp_tunnel_measured  Temp_tunnel_set  Vanne_opening_rate  \
# 0                    11.9               10            8.152407
# 1                    11.7               10           18.132671
# 2                    11.5               10           29.087076
# 3                    11.1               10           35.764454
# 4                    10.7               10           38.100580
# ..                    ...              ...                 ...
# 869                 -85.7              -86           27.456482
# 870                 -85.9              -86           22.515778
# 871                 -85.9              -86           25.934847
# 872                 -85.9              -86           24.692324
# 873                 -85.9              -86           25.277805
#
#                                _time
# 0   2020-09-05 00:22:07.311000+00:00
# 1   2020-09-05 00:23:08.729000+00:00
# 2   2020-09-05 00:24:07.310000+00:00
# 3   2020-09-05 00:25:08.745000+00:00
# 4   2020-09-05 00:26:07.315000+00:00
# ..                               ...
# 869 2020-09-10 10:09:48.272000+00:00
# 870 2020-09-10 10:10:48.277000+00:00
# 871 2020-09-10 10:12:48.266000+00:00
# 872 2020-09-10 10:14:48.312000+00:00
# 873 2020-09-10 10:15:48.283000+00:00
#
# [874 rows x 26 columns]

# %%
df_w_o_prod_flow[["LIN_flow", "Product_flow", "Cumulative_LIN_flow", "Cumulative_product_flow", "_time"]].head()
# Out:
#      LIN_flow  Product_flow  Cumulative_LIN_flow  Cumulative_product_flow  \
# 0    6.517969      0.418350               317404                   158249
# 1   28.976774      1.302090               317404                   158249
# 2   53.076607      1.991233               317404                   158249
# 3  102.567280      2.896480               317407                   158249
# 4  142.960620      2.801739               317410                   158249
#
#                              _time
# 0 2020-09-05 00:22:07.311000+00:00
# 1 2020-09-05 00:23:08.729000+00:00
# 2 2020-09-05 00:24:07.310000+00:00
# 3 2020-09-05 00:25:08.745000+00:00
# 4 2020-09-05 00:26:07.315000+00:00

# %%
df_w_o_prod_flow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 874 entries, 0 to 873
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   BeltAmpere_belt1         874 non-null    float64
#  1   BeltAmpere_belt2         874 non-null    float64
#  2   BeltAmpere_belt3         874 non-null    float64
#  3   Cumulative_LIN_flow      874 non-null    int64
#  4   Cumulative_product_flow  874 non-null    int64
#  5   FanAmpere_exhaust1       874 non-null    float64
#  6   FanAmpere_exhaust2       874 non-null    float64
#  7   FanAmpere_side           874 non-null    float64
#  8   FanAmpere_top            874 non-null    float64
#  9   Fanspeed_exhaust1        874 non-null    int64
#  10  Fanspeed_exhaust2        874 non-null    int64
#  11  Fanspeed_side            874 non-null    int64
#  12  Fanspeed_top             874 non-null    int64
#  13  LIN_flow                 874 non-null    float64
#  14  Product_flow             874 non-null    float64
#  15  ResidenceTime_belt1      874 non-null    int64
#  16  ResidenceTime_belt2      874 non-null    int64
#  17  ResidenceTime_belt3      874 non-null    int64
#  18  Temp_exhaust_in          874 non-null    float64
#  19  Temp_exhaust_out         874 non-null    float64
#  20  Temp_product_in          874 non-null    float64
#  21  Temp_product_out         874 non-null    float64
#  22  Temp_tunnel_measured     874 non-null    float64
#  23  Temp_tunnel_set          874 non-null    int64
#  24  Vanne_opening_rate       874 non-null    float64
#  25  _time                    874 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(15), int64(10)
# memory usage: 177.7 KB

# %%
x_time = df_w_o_prod_flow["_time"]
y_LIN = df_w_o_prod_flow["LIN_flow"]
y_PROD = df_w_o_prod_flow["Product_flow"]

# %%
plt.figure(figsize=(35, 35))
ax = plt.subplot(3,3,3)
plt.plot(x_time, y_LIN, color="red", label="LIN_flow")
plt.plot(x_time, y_PROD, color="black", label="Product_flow", alpha=0.5)
plt.xlabel("Time")
plt.ylabel("LIN_flow")
plt.grid(True)
plt.legend()

# %%
df_w_o_prod_flow.describe()
named_cols = df_w_o_prod_flow.columns[:-1]
named_cols
# Out:
# Index(['BeltAmpere_belt1', 'BeltAmpere_belt2', 'BeltAmpere_belt3',
#        'Cumulative_LIN_flow', 'Cumulative_product_flow', 'FanAmpere_exhaust1',
#        'FanAmpere_exhaust2', 'FanAmpere_side', 'FanAmpere_top',
#        'Fanspeed_exhaust1', 'Fanspeed_exhaust2', 'Fanspeed_side',
#        'Fanspeed_top', 'LIN_flow', 'Product_flow', 'ResidenceTime_belt1',
#        'ResidenceTime_belt2', 'ResidenceTime_belt3', 'Temp_exhaust_in',
#        'Temp_exhaust_out', 'Temp_product_in', 'Temp_product_out',
#        'Temp_tunnel_measured', 'Temp_tunnel_set', 'Vanne_opening_rate'],
#       dtype='object')

# %%
#Данные чистые, пустых значений нет
df_w_o_prod_flow.isnull().values.any()
df_w_o_prod_flow["_time"] = pd.to_datetime(df_w_o_prod_flow["_time"])

# %%
y = df_w_o_prod_flow["LIN_flow"]
x = df_w_o_prod_flow

# %%
print('Матрица корреляций всех признаков, кроме последнего:\n', x.iloc[:, :-1].corr())
print('\n')

print(x.shape)
# Out:
# Матрица корреляций всех признаков, кроме последнего:
#                           BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# BeltAmpere_belt1                 1.000000          0.926078          0.921953
# BeltAmpere_belt2                 0.926078          1.000000          0.999331
# BeltAmpere_belt3                 0.921953          0.999331          1.000000
# Cumulative_LIN_flow              0.579312          0.741231          0.732469
# Cumulative_product_flow          0.230664          0.368482          0.354711
# FanAmpere_exhaust1               0.758829          0.768707          0.763121
# FanAmpere_exhaust2               0.709380          0.742218          0.737191
# FanAmpere_side                   0.883557          0.919990          0.915708
# FanAmpere_top                    0.885448          0.915484          0.911025
# Fanspeed_exhaust1                0.404242          0.477891          0.473229
# Fanspeed_exhaust2                0.551646          0.675039          0.672526
# Fanspeed_side                    0.569223          0.516911          0.508572
# Fanspeed_top                     0.667207          0.772019          0.768294
# LIN_flow                         0.500255          0.693127          0.689779
# Product_flow                     0.294062          0.466093          0.454997
# ResidenceTime_belt1              0.765048          0.492332          0.484911
# ResidenceTime_belt2              0.928033          0.809107          0.804946
# ResidenceTime_belt3              0.891207          0.778600          0.774642
# Temp_exhaust_in                 -0.539761         -0.592762         -0.597695
# Temp_exhaust_out                -0.323673         -0.485545         -0.480237
# Temp_product_in                  0.246706          0.395528          0.382042
# Temp_product_out                -0.314439         -0.478398         -0.479821
# Temp_tunnel_measured            -0.724664         -0.907181         -0.907544
# Temp_tunnel_set                 -0.713424         -0.897740         -0.898537
# Vanne_opening_rate               0.479963          0.543403          0.540899
#
#                          Cumulative_LIN_flow  Cumulative_product_flow  \
# BeltAmpere_belt1                    0.579312                 0.230664
# BeltAmpere_belt2                    0.741231                 0.368482
# BeltAmpere_belt3                    0.732469                 0.354711
# Cumulative_LIN_flow                 1.000000                 0.881303
# Cumulative_product_flow             0.881303                 1.000000
# FanAmpere_exhaust1                  0.504883                 0.223810
# FanAmpere_exhaust2                  0.501368                 0.222680
# FanAmpere_side                      0.631674                 0.313189
# FanAmpere_top                       0.621343                 0.304072
# Fanspeed_exhaust1                   0.353792                 0.171464
# Fanspeed_exhaust2                   0.523822                 0.280495
# Fanspeed_side                       0.254443                 0.129297
# Fanspeed_top                        0.565249                 0.324360
# LIN_flow                            0.744174                 0.527965
# Product_flow                        0.739095                 0.675921
# ResidenceTime_belt1                 0.142766                -0.055721
# ResidenceTime_belt2                 0.440858                 0.121575
# ResidenceTime_belt3                 0.412478                 0.103068
# Temp_exhaust_in                    -0.182700                 0.186820
# Temp_exhaust_out                   -0.653066                -0.540022
# Temp_product_in                     0.736468                 0.728302
# Temp_product_out                   -0.518302                -0.384935
# Temp_tunnel_measured               -0.794166                -0.439409
# Temp_tunnel_set                    -0.791358                -0.442639
# Vanne_opening_rate                  0.416407                 0.202182
#
#                          FanAmpere_exhaust1  FanAmpere_exhaust2  \
# BeltAmpere_belt1                   0.758829            0.709380
# BeltAmpere_belt2                   0.768707            0.742218
# BeltAmpere_belt3                   0.763121            0.737191
# Cumulative_LIN_flow                0.504883            0.501368
# Cumulative_product_flow            0.223810            0.222680
# FanAmpere_exhaust1                 1.000000            0.988494
# FanAmpere_exhaust2                 0.988494            1.000000
# FanAmpere_side                     0.852956            0.819527
# FanAmpere_top                      0.854945            0.820526
# Fanspeed_exhaust1                  0.872413            0.918913
# Fanspeed_exhaust2                  0.927196            0.953271
# Fanspeed_side                      0.763325            0.725389
# Fanspeed_top                       0.826792            0.810208
# LIN_flow                           0.571033            0.590666
# Product_flow                       0.391657            0.420190
# ResidenceTime_belt1                0.391476            0.323318
# ResidenceTime_belt2                0.598273            0.543308
# ResidenceTime_belt3                0.573258            0.520040
# Temp_exhaust_in                   -0.488368           -0.481381
# Temp_exhaust_out                  -0.226754           -0.237060
# Temp_product_in                    0.385157            0.419588
# Temp_product_out                  -0.346976           -0.361752
# Temp_tunnel_measured              -0.649277           -0.651131
# Temp_tunnel_set                   -0.617797           -0.621711
# Vanne_opening_rate                 0.548606            0.560906
#
#                          FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# BeltAmpere_belt1               0.883557       0.885448           0.404242
# BeltAmpere_belt2               0.919990       0.915484           0.477891
# BeltAmpere_belt3               0.915708       0.911025           0.473229
# Cumulative_LIN_flow            0.631674       0.621343           0.353792
# Cumulative_product_flow        0.313189       0.304072           0.171464
# FanAmpere_exhaust1             0.852956       0.854945           0.872413
# FanAmpere_exhaust2             0.819527       0.820526           0.918913
# FanAmpere_side                 1.000000       0.999766           0.568855
# FanAmpere_top                  0.999766       1.000000           0.568850
# Fanspeed_exhaust1              0.568855       0.568850           1.000000
# Fanspeed_exhaust2              0.756242       0.753748           0.934395
# Fanspeed_side                  0.783077       0.790907           0.588225
# Fanspeed_top                   0.925351       0.924070           0.653441
# LIN_flow                       0.614725       0.605287           0.516644
# Product_flow                   0.407670       0.399043           0.406099
# ResidenceTime_belt1            0.468874       0.478895           0.044840
# ResidenceTime_belt2            0.734417       0.738237           0.234592
# ResidenceTime_belt3            0.707479       0.711345           0.221665
# Temp_exhaust_in               -0.534533      -0.533815          -0.339773
# Temp_exhaust_out              -0.415430      -0.406271          -0.116328
# Temp_product_in                0.340997       0.333336           0.445493
# Temp_product_out              -0.419615      -0.408585          -0.297490
# Temp_tunnel_measured          -0.798820      -0.789491          -0.461154
# Temp_tunnel_set               -0.793861      -0.784482          -0.429497
# Vanne_opening_rate             0.536603       0.535957           0.486375
#
#                          ...  ResidenceTime_belt1  ResidenceTime_belt2  \
# BeltAmpere_belt1         ...             0.765048             0.928033
# BeltAmpere_belt2         ...             0.492332             0.809107
# BeltAmpere_belt3         ...             0.484911             0.804946
# Cumulative_LIN_flow      ...             0.142766             0.440858
# Cumulative_product_flow  ...            -0.055721             0.121575
# FanAmpere_exhaust1       ...             0.391476             0.598273
# FanAmpere_exhaust2       ...             0.323318             0.543308
# FanAmpere_side           ...             0.468874             0.734417
# FanAmpere_top            ...             0.478895             0.738237
# Fanspeed_exhaust1        ...             0.044840             0.234592
# Fanspeed_exhaust2        ...             0.048535             0.341773
# Fanspeed_side            ...             0.306540             0.402859
# Fanspeed_top             ...             0.154481             0.457768
# LIN_flow                 ...             0.027056             0.352935
# Product_flow             ...            -0.071857             0.171004
# ResidenceTime_belt1      ...             1.000000             0.854395
# ResidenceTime_belt2      ...             0.854395             1.000000
# ResidenceTime_belt3      ...             0.817445             0.987103
# Temp_exhaust_in          ...            -0.272051            -0.531279
# Temp_exhaust_out         ...             0.025708            -0.218266
# Temp_product_in          ...            -0.060357             0.138462
# Temp_product_out         ...             0.042414            -0.187478
# Temp_tunnel_measured     ...            -0.194663            -0.592844
# Temp_tunnel_set          ...            -0.199033            -0.591762
# Vanne_opening_rate       ...             0.200984             0.382852
#
#                          ResidenceTime_belt3  Temp_exhaust_in  \
# BeltAmpere_belt1                    0.891207        -0.539761
# BeltAmpere_belt2                    0.778600        -0.592762
# BeltAmpere_belt3                    0.774642        -0.597695
# Cumulative_LIN_flow                 0.412478        -0.182700
# Cumulative_product_flow             0.103068         0.186820
# FanAmpere_exhaust1                  0.573258        -0.488368
# FanAmpere_exhaust2                  0.520040        -0.481381
# FanAmpere_side                      0.707479        -0.534533
# FanAmpere_top                       0.711345        -0.533815
# Fanspeed_exhaust1                   0.221665        -0.339773
# Fanspeed_exhaust2                   0.327713        -0.423798
# Fanspeed_side                       0.387551        -0.206361
# Fanspeed_top                        0.442759        -0.423271
# LIN_flow                            0.335486        -0.448574
# Product_flow                        0.155513        -0.161500
# ResidenceTime_belt1                 0.817445        -0.272051
# ResidenceTime_belt2                 0.987103        -0.531279
# ResidenceTime_belt3                 1.000000        -0.538582
# Temp_exhaust_in                    -0.538582         1.000000
# Temp_exhaust_out                   -0.203899         0.050509
# Temp_product_in                     0.127547        -0.108745
# Temp_product_out                   -0.165325         0.253873
# Temp_tunnel_measured               -0.574570         0.636511
# Temp_tunnel_set                    -0.573418         0.619998
# Vanne_opening_rate                  0.367370        -0.360702
#
#                          Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# BeltAmpere_belt1                -0.323673         0.246706         -0.314439
# BeltAmpere_belt2                -0.485545         0.395528         -0.478398
# BeltAmpere_belt3                -0.480237         0.382042         -0.479821
# Cumulative_LIN_flow             -0.653066         0.736468         -0.518302
# Cumulative_product_flow         -0.540022         0.728302         -0.384935
# FanAmpere_exhaust1              -0.226754         0.385157         -0.346976
# FanAmpere_exhaust2              -0.237060         0.419588         -0.361752
# FanAmpere_side                  -0.415430         0.340997         -0.419615
# FanAmpere_top                   -0.406271         0.333336         -0.408585
# Fanspeed_exhaust1               -0.116328         0.445493         -0.297490
# Fanspeed_exhaust2               -0.283935         0.467127         -0.409009
# Fanspeed_side                   -0.140286         0.145774         -0.177566
# Fanspeed_top                    -0.402138         0.354097         -0.424344
# LIN_flow                        -0.600602         0.766707         -0.483400
# Product_flow                    -0.616341         0.889019         -0.362898
# ResidenceTime_belt1              0.025708        -0.060357          0.042414
# ResidenceTime_belt2             -0.218266         0.138462         -0.187478
# ResidenceTime_belt3             -0.203899         0.127547         -0.165325
# Temp_exhaust_in                  0.050509        -0.108745          0.253873
# Temp_exhaust_out                 1.000000        -0.527616          0.283877
# Temp_product_in                 -0.527616         1.000000         -0.387268
# Temp_product_out                 0.283877        -0.387268          1.000000
# Temp_tunnel_measured             0.608183        -0.512922          0.503078
# Temp_tunnel_set                  0.602512        -0.521148          0.495971
# Vanne_opening_rate              -0.269942         0.497145         -0.290729
#
#                          Temp_tunnel_measured  Temp_tunnel_set  \
# BeltAmpere_belt1                    -0.724664        -0.713424
# BeltAmpere_belt2                    -0.907181        -0.897740
# BeltAmpere_belt3                    -0.907544        -0.898537
# Cumulative_LIN_flow                 -0.794166        -0.791358
# Cumulative_product_flow             -0.439409        -0.442639
# FanAmpere_exhaust1                  -0.649277        -0.617797
# FanAmpere_exhaust2                  -0.651131        -0.621711
# FanAmpere_side                      -0.798820        -0.793861
# FanAmpere_top                       -0.789491        -0.784482
# Fanspeed_exhaust1                   -0.461154        -0.429497
# Fanspeed_exhaust2                   -0.657788        -0.634095
# Fanspeed_side                       -0.321780        -0.295997
# Fanspeed_top                        -0.708128        -0.689579
# LIN_flow                            -0.790149        -0.789959
# Product_flow                        -0.587194        -0.594006
# ResidenceTime_belt1                 -0.194663        -0.199033
# ResidenceTime_belt2                 -0.592844        -0.591762
# ResidenceTime_belt3                 -0.574570        -0.573418
# Temp_exhaust_in                      0.636511         0.619998
# Temp_exhaust_out                     0.608183         0.602512
# Temp_product_in                     -0.512922        -0.521148
# Temp_product_out                     0.503078         0.495971
# Temp_tunnel_measured                 1.000000         0.986481
# Temp_tunnel_set                      0.986481         1.000000
# Vanne_opening_rate                  -0.504597        -0.541476
#
#                          Vanne_opening_rate
# BeltAmpere_belt1                   0.479963
# BeltAmpere_belt2                   0.543403
# BeltAmpere_belt3                   0.540899
# Cumulative_LIN_flow                0.416407
# Cumulative_product_flow            0.202182
# FanAmpere_exhaust1                 0.548606
# FanAmpere_exhaust2                 0.560906
# FanAmpere_side                     0.536603
# FanAmpere_top                      0.535957
# Fanspeed_exhaust1                  0.486375
# Fanspeed_exhaust2                  0.553192
# Fanspeed_side                      0.344777
# Fanspeed_top                       0.482467
# LIN_flow                           0.586924
# Product_flow                       0.490065
# ResidenceTime_belt1                0.200984
# ResidenceTime_belt2                0.382852
# ResidenceTime_belt3                0.367370
# Temp_exhaust_in                   -0.360702
# Temp_exhaust_out                  -0.269942
# Temp_product_in                    0.497145
# Temp_product_out                  -0.290729
# Temp_tunnel_measured              -0.504597
# Temp_tunnel_set                   -0.541476
# Vanne_opening_rate                 1.000000
#
# [25 rows x 25 columns]
#
#
# (874, 26)

# %%
# Посчитайте корреляции всех признаков, кроме последнего, с последним с помощью метода corrwith:
corr_ = x.corrwith(y, method='spearman')
# print(corr_, end='\n')
sa = dict(corr_).items()
sorted(sa, key = lambda x : x[1])
# max(sa, key = lambda x : x[1])
# Out:
# [('Temp_tunnel_set', -0.5883647948858682),
#  ('Temp_exhaust_out', -0.5744010100856227),
#  ('Temp_tunnel_measured', -0.551003603450358),
#  ('Temp_product_out', -0.42135578994203),
#  ('Temp_exhaust_in', -0.2736481432556655),
#  ('FanAmpere_top', 0.16512379500730376),
#  ('BeltAmpere_belt3', 0.2685042403854621),
#  ('ResidenceTime_belt2', 0.2829820116116096),
#  ('ResidenceTime_belt3', 0.28420267080207817),
#  ('FanAmpere_exhaust1', 0.3089816826689902),
#  ('ResidenceTime_belt1', 0.3124563780202656),
#  ('Fanspeed_side', 0.3205265622528417),
#  ('FanAmpere_exhaust2', 0.4114466819594148),
#  ('BeltAmpere_belt1', 0.419842636652969),
#  ('Fanspeed_top', 0.4373152052841255),
#  ('FanAmpere_side', 0.4757800500911842),
#  ('Fanspeed_exhaust2', 0.4976963692128322),
#  ('Fanspeed_exhaust1', 0.5059596320361883),
#  ('Vanne_opening_rate', 0.5389263167217495),
#  ('BeltAmpere_belt2', 0.5547686763402422),
#  ('Cumulative_product_flow', 0.6741843959463496),
#  ('Cumulative_LIN_flow', 0.6765392617798859),
#  ('Temp_product_in', 0.7714099747011057),
#  ('Product_flow', 0.8362507973205087),
#  ('LIN_flow', 1.0)]

# %%
plt.figure(figsize=(25, 25))
sns.heatmap(x[::].corr(), square=True, annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(nrows=9, ncols=3, figsize=(25, 55))
colormap = ["red", "green", "blue"]
for idx, feature in enumerate(x.columns[:-1]):
    x.plot(feature, "LIN_flow", subplots=True, kind="scatter", 
           ax=axes[idx // 3, idx % 3], color=colormap[idx % 3], grid=True)

# %%
x.hist(figsize=(20, 35), bins=100);

# %%
x.mean()
# Out:
# BeltAmpere_belt1                2.254012
# BeltAmpere_belt2                3.251982
# BeltAmpere_belt3                3.176659
# Cumulative_LIN_flow        335716.195652
# Cumulative_product_flow    164111.508009
# FanAmpere_exhaust1              2.140240
# FanAmpere_exhaust2              2.481412
# FanAmpere_side                  7.294226
# FanAmpere_top                   7.437878
# Fanspeed_exhaust1              56.052632
# Fanspeed_exhaust2              69.187643
# Fanspeed_side                  38.009153
# Fanspeed_top                   63.066362
# LIN_flow                      835.616443
# Product_flow                  738.982124
# ResidenceTime_belt1            82.929062
# ResidenceTime_belt2           143.032037
# ResidenceTime_belt3           143.855835
# Temp_exhaust_in               -10.742906
# Temp_exhaust_out                5.211670
# Temp_product_in                 7.652874
# Temp_product_out              -12.054773
# Temp_tunnel_measured          -72.775629
# Temp_tunnel_set               -73.620137
# Vanne_opening_rate             27.892190
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler, scale
from sklearn.utils import shuffle
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x.iloc[:, :-1])

# %%
x_scaled = pd.DataFrame(x_scaled, columns=named_cols)
x_scaled.hist(figsize=(20, 35), bins=100);

# %%
plt.figure(figsize=(20, 55))
for i, feature in enumerate(x_scaled.columns):
    plt.subplot(9, 3, i+1)
    sns.kdeplot(x[feature])
    plt.xlabel(feature)
plt.show()

# %%
df_shuffled = shuffle(x, random_state=123)
X = df_shuffled[df_shuffled.columns[:-1]]
X = scale(df_shuffled.drop(["LIN_flow", "_time"], 1))
y = df_shuffled["LIN_flow"]

df_shuffled = df_shuffled.drop(["LIN_flow"], 1)
print(X)
print('\n')
print(y)
# Out:
# [[ 0.22910599  0.35876476  0.40263563 ... -0.60758927 -0.635774
#    0.69408242]
#  [ 0.22265294  0.38071986  0.37376493 ... -0.43006721 -0.42822925
#    0.24299895]
#  [ 0.21619976  0.37840881  0.34548347 ... -0.45911627 -0.42822925
#   -0.28666982]
#  ...
#  [ 0.2363656   0.34547626  0.37317568 ... -0.53335277 -0.60118321
#    1.77688313]
#  [ 0.22749272  0.32814326  0.35667816 ... -0.53658044 -0.56659242
#    0.58763336]
#  [ 0.22426607  0.36858679  0.33782376 ... -0.43652256 -0.42822925
#    0.13334434]]
#
#
# 372    1133.463900
# 517    1315.660400
# 791    1086.152700
# 145     691.787000
# 151     938.515260
#           ...
# 98      103.925545
# 322     883.739900
# 382     931.782700
# 365     876.326800
# 510     939.815250
# Name: LIN_flow, Length: 874, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
regr = LinearRegression()
regr.fit(X, y)
print('Коэффициенты: ')
list(zip(df_shuffled.columns, regr.coef_))
# Out:
# Коэффициенты:
# [('BeltAmpere_belt1', -32.9341400688907),
#  ('BeltAmpere_belt2', -358.2827567982713),
#  ('BeltAmpere_belt3', 730.7308943828996),
#  ('Cumulative_LIN_flow', -728.7428396344851),
#  ('Cumulative_product_flow', 423.88589092151517),
#  ('FanAmpere_exhaust1', 128.3067924065716),
#  ('FanAmpere_exhaust2', -406.88106666564994),
#  ('FanAmpere_side', -2677.028803156742),
#  ('FanAmpere_top', 3482.5944227705054),
#  ('Fanspeed_exhaust1', 105.48989096940095),
#  ('Fanspeed_exhaust2', 236.0445818466101),
#  ('Fanspeed_side', -636.0833105580948),
#  ('Fanspeed_top', 87.64204002458357),
#  ('Product_flow', 112.90508601853277),
#  ('ResidenceTime_belt1', 4.420252859163338),
#  ('ResidenceTime_belt2', -154.8267187589223),
#  ('ResidenceTime_belt3', 8.46381843584529),
#  ('Temp_exhaust_in', -19.995339454597946),
#  ('Temp_exhaust_out', -59.16463320840835),
#  ('Temp_product_in', 198.6180745468365),
#  ('Temp_product_out', 9.471605799475906),
#  ('Temp_tunnel_measured', -363.47462662617846),
#  ('Temp_tunnel_set', 589.2601139838563),
#  ('Vanne_opening_rate', 16.973240049604648)]

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
regLasso = Lasso()
regLasso.fit(X, y)
print('Коэффициенты:')
list(zip(df_shuffled.columns, regLasso.coef_))
# Out:
# Коэффициенты:
# [('BeltAmpere_belt1', -0.0),
#  ('BeltAmpere_belt2', 0.0),
#  ('BeltAmpere_belt3', 185.957580535992),
#  ('Cumulative_LIN_flow', -81.83147800339272),
#  ('Cumulative_product_flow', 13.850356437922853),
#  ('FanAmpere_exhaust1', 35.8206296589792),
#  ('FanAmpere_exhaust2', -0.0),
#  ('FanAmpere_side', 101.7719473392673),
#  ('FanAmpere_top', 0.0),
#  ('Fanspeed_exhaust1', 0.0),
#  ('Fanspeed_exhaust2', 0.0),
#  ('Fanspeed_side', -141.69798307369177),
#  ('Fanspeed_top', 67.94451613608516),
#  ('Product_flow', 114.70678866960577),
#  ('ResidenceTime_belt1', -21.423339366467484),
#  ('ResidenceTime_belt2', -74.75737239639757),
#  ('ResidenceTime_belt3', -0.06742162085195999),
#  ('Temp_exhaust_in', -50.91532146464874),
#  ('Temp_exhaust_out', -37.01888514601227),
#  ('Temp_product_in', 141.38985035152288),
#  ('Temp_product_out', 0.0),
#  ('Temp_tunnel_measured', 0.0),
#  ('Temp_tunnel_set', 42.5839436025951),
#  ('Vanne_opening_rate', 17.233525695703506)]

# %%
regRidge = Ridge()
regRidge.fit(X, y)
print('Коэффициенты: ')
list(zip(df_shuffled.columns, regRidge.coef_))
# Out:
# Коэффициенты:
# [('BeltAmpere_belt1', -21.756895228446382),
#  ('BeltAmpere_belt2', 30.66856322634389),
#  ('BeltAmpere_belt3', 281.12304152293973),
#  ('Cumulative_LIN_flow', -413.6967483707529),
#  ('Cumulative_product_flow', 225.36090242421065),
#  ('FanAmpere_exhaust1', 135.36491725973073),
#  ('FanAmpere_exhaust2', -212.46075088636726),
#  ('FanAmpere_side', 167.73315456090313),
#  ('FanAmpere_top', 245.82796152855056),
#  ('Fanspeed_exhaust1', 70.41877727539647),
#  ('Fanspeed_exhaust2', 57.88167896123637),
#  ('Fanspeed_side', -352.13999238406575),
#  ('Fanspeed_top', 71.4335476582651),
#  ('Product_flow', 110.55543687954676),
#  ('ResidenceTime_belt1', -14.065897486796622),
#  ('ResidenceTime_belt2', -113.26124550617564),
#  ('ResidenceTime_belt3', -0.32088673666540884),
#  ('Temp_exhaust_in', -47.858447216470196),
#  ('Temp_exhaust_out', -52.554919501260265),
#  ('Temp_product_in', 165.167906621806),
#  ('Temp_product_out', 13.192218415481296),
#  ('Temp_tunnel_measured', -113.30737116324698),
#  ('Temp_tunnel_set', 256.7090108347167),
#  ('Vanne_opening_rate', 21.035470860029186)]

# %%
# Код 3.1 (1 балл)
alphas = np.arange(1, 500, 50)
coefs_lasso = np.zeros((alphas.shape[0], X.shape[1])) # матрица весов размера (число регрессоров) x (число признаков)
coefs_ridge = np.zeros((alphas.shape[0], X.shape[1]))
# Для каждого значения коэффициента из alphas обучите регрессор Lasso
# и запишите веса в соответствующую строку матрицы coefs_lasso (вспомните встроенную в python функцию enumerate),
# а затем обучите Ridge и запишите веса в coefs_ridge.

for i, item in enumerate(alphas):
    reg_Lasso = Lasso(alpha = alphas[i])
    reg_Lasso.fit(X, y)
    coefs_lasso[i,:] = reg_Lasso.coef_

for i, item in enumerate(alphas):
    reg_Ridge = Ridge(alpha = alphas[i])
    reg_Ridge.fit(X, y)
    coefs_ridge[i,:] = reg_Ridge.coef_

# %%
plt.figure(figsize=(8, 5))

for coef, feature in zip(coefs_lasso.T, df_shuffled.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))
    
plt.legend(loc="upper right", bbox_to_anchor=(1.6, 1))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Lasso")

plt.figure(figsize=(8, 5))

for coef, feature in zip(coefs_ridge.T, df_shuffled.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))
    
plt.legend(loc="upper right", bbox_to_anchor=(1.6, 1))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Ridge")
# Out:
# Text(0.5, 1.0, 'Ridge')

# %%
from sklearn.linear_model import LassoCV

# %%
# Код 3.2 (1 балл)
# Обучите регрессор LassoCV на всех параметрах регуляризации из alpha
# Постройте график _усредненного_ по строкам MSE в зависимости от alpha. 
# Выведите выбранное alpha, а также пары "признак-коэффициент" для обученного вектора коэффициентов

alphas = np.arange(1, 100, 5)
regLassoCV = LassoCV(alphas=alphas)
regLassoCV.fit(X, y)
print('Матрица переменной mse_path_: \n', regLassoCV.mse_path_)

plt.plot(regLassoCV.alphas_, regLassoCV.mse_path_.mean(axis=1))
plt.xlabel('alphas')
plt.ylabel('MSE')
plt.show()

print('Выбранное alpha:', regLassoCV.alpha_, '\n')
print('Вектор коэффициентов для выбранного alpha:')
list(zip(df_shuffled.columns, regLassoCV.coef_))
# Out:
# Матрица переменной mse_path_:
#  [[35503.95283035 44808.46465247 42312.9295626  48007.7953782
#   50045.73162014]
#  [34475.97751014 43631.19573445 40873.89405517 46801.26114225
#   48435.09000262]
#  [33508.94213543 42515.51107246 39510.94212278 45654.50722478
#   46815.48670061]
#  [32605.64273444 41461.39032462 38224.06633328 44451.49263686
#   45217.00116892]
#  [31697.27252564 40468.83025735 37013.21765027 43205.93028253
#   43709.00900936]
#  [30866.33508522 39537.8303565  35826.96273851 41998.21475623
#   42291.3795505 ]
#  [30112.83876026 38668.39054037 34658.55658469 40862.07237732
#   40964.16593087]
#  [29436.78515667 37860.44740332 33571.74372327 39797.06750333
#   39727.38064688]
#  [28838.19019715 37114.11970372 32571.12854213 38803.36859496
#   38581.11192265]
#  [28280.34309411 36318.70306944 31656.72900679 37880.97888122
#   37486.86718222]
#  [27713.59088576 35411.52330538 30828.55099651 37029.88916435
#   36398.34865437]
#  [27243.44235658 34527.49173947 29903.81466615 36126.76898817
#   35420.3405057 ]
#  [26869.78240122 33754.47266547 29015.67225562 35167.02261358
#   34552.85387997]
#  [26592.63815489 33077.22272088 28237.4594783  34293.47263283
#   33769.13858734]
#  [26358.86642406 32464.77240247 27569.13602084 33469.85204363
#   33050.9110944 ]
#  [26015.8785327  31838.17536369 26850.24902343 32757.47553706
#   32349.78177198]
#  [25691.0901933  31365.81038685 25918.43060829 32199.14670692
#   31601.9328289 ]
#  [25096.52772952 30675.59764958 24584.68871488 31159.87237058
#   30919.49123827]
#  [23906.0541209  29313.1322274  23122.84395073 30045.15552786
#   30257.95082963]
#  [21684.16440535 27352.12815702 21347.80359675 29566.32164138
#   27514.41899083]]
# Выбранное alpha: 1
#
# Вектор коэффициентов для выбранного alpha:
# [('BeltAmpere_belt1', -0.0),
#  ('BeltAmpere_belt2', 0.0),
#  ('BeltAmpere_belt3', 185.957580535992),
#  ('Cumulative_LIN_flow', -81.83147800339272),
#  ('Cumulative_product_flow', 13.850356437922853),
#  ('FanAmpere_exhaust1', 35.8206296589792),
#  ('FanAmpere_exhaust2', -0.0),
#  ('FanAmpere_side', 101.7719473392673),
#  ('FanAmpere_top', 0.0),
#  ('Fanspeed_exhaust1', 0.0),
#  ('Fanspeed_exhaust2', 0.0),
#  ('Fanspeed_side', -141.69798307369177),
#  ('Fanspeed_top', 67.94451613608516),
#  ('Product_flow', 114.70678866960577),
#  ('ResidenceTime_belt1', -21.423339366467484),
#  ('ResidenceTime_belt2', -74.75737239639757),
#  ('ResidenceTime_belt3', -0.06742162085195999),
#  ('Temp_exhaust_in', -50.91532146464874),
#  ('Temp_exhaust_out', -37.01888514601227),
#  ('Temp_product_in', 141.38985035152288),
#  ('Temp_product_out', 0.0),
#  ('Temp_tunnel_measured', 0.0),
#  ('Temp_tunnel_set', 42.5839436025951),
#  ('Vanne_opening_rate', 17.233525695703506)]

# %%
min_alphas = []
for i in range(3):
    z = dict(zip(regLassoCV.alphas_, regLassoCV.mse_path_[:, i]))
    min_alphas.append(sorted(z, key=z.get)[0])
    plt.figure(figsize=(8, 5))
    plt.plot(regLassoCV.alphas_, regLassoCV.mse_path_[:, i], label='mse{} from alpha'.format(i))
    plt.legend(loc='best')
    plt.xlabel('alpha')
    plt.ylabel('mse')

min_alphas
# Out:
# [1, 1, 1]
