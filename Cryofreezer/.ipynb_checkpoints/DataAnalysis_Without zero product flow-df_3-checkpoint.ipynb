# %%
# ondoing main libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# import jupyterthemes as jt
# from jupyterthemes import jtplot
# !jt -t onedork -ofs 10 -dfs 9 -nfs 11 -tfs 11
# jtplot.style(theme = 'onedork', fscale = 1.4 , context = 'notebook', ticks = True, 
#              grid = False)

# %%
# !jt -r
# Out:
# Reset css and font defaults in:
# /home/tater/.jupyter/custom &
# /home/tater/.local/share/jupyter/nbextensions

# %%
# hiding possible warning in the system
import warnings
warnings.filterwarnings('ignore')

# %%
df_1 = pd.read_csv("Cryofreezer_all_variables_29.csv", delimiter=',')
df_2 = pd.read_csv("Cryofreezer_all_variables_30.csv", delimiter=',')
df_3 = pd.read_csv("Cryofreezer_all_variables_31.csv", delimiter=',')
df_4 = pd.read_csv("Cryofreezer_all_variables_32.csv", delimiter=',')
df_5 = pd.read_csv("Cryofreezer_all_variables_33.csv", delimiter=',')

# %%
# entering a deltatime between to moments of experiments
def deltatime(dataframe):
    begin = dataframe[0]
    for i in range(len(dataframe)):   
        cur = dataframe[i]
        delta = cur - begin
        dataframe[i] = delta.seconds

# %%
#file concatanation
df_all = df_2
df_all
# Out:
#       BeltAmpere_belt1  BeltAmpere_belt1_qc  BeltAmpere_belt2  \
# 0             0.000000          -2138963968          0.000000
# 1             2.422485                    0          3.634644
# 2             0.000000          -2138963968          0.000000
# 3             2.426758                    0          3.676758
# 4             2.426147                    0          3.619385
# ...                ...                  ...               ...
# 7995          0.002441                    0          0.002441
# 7996          0.002441                    0          0.002441
# 7997          0.002441                    0          0.001831
# 7998          0.000000          -2138963968          0.000000
# 7999          0.002441                    0          0.002441
#
#       BeltAmpere_belt2_qc  BeltAmpere_belt3  BeltAmpere_belt3_qc  \
# 0             -2138963968          0.000000          -2138963968
# 1                       0          3.515625                    0
# 2             -2138963968          0.000000          -2138963968
# 3                       0          3.535156                    0
# 4                       0          3.523560                    0
# ...                   ...               ...                  ...
# 7995                    0          0.002441                    0
# 7996                    0          0.002441                    0
# 7997                    0          0.002441                    0
# 7998          -2138963968          0.000000          -2138963968
# 7999                    0          0.002441                    0
#
#       Cumulative_LIN_flow  Cumulative_LIN_flow_qc  Cumulative_product_flow  \
# 0                       0             -2138963968                        0
# 1                  349032                       0                   176026
# 2                       0             -2138963968                        0
# 3                  349060                       0                   176047
# 4                  349076                       0                   176057
# ...                   ...                     ...                      ...
# 7995               388352                       0                   210730
# 7996               388356                       0                   210730
# 7997               388359                       0                   210730
# 7998                    0             -2138963968                        0
# 7999               388366                       0                   210730
#
#       Cumulative_product_flow_qc  ...  Temp_product_in_qc  Temp_product_out  \
# 0                    -2138963968  ...         -2138963968          0.000000
# 1                              0  ...                   0        -23.275791
# 2                    -2138963968  ...         -2138963968          0.000000
# 3                              0  ...                   0          0.000000
# 4                              0  ...                   0        -23.905650
# ...                          ...  ...                 ...               ...
# 7995                           0  ...                   0          0.000000
# 7996                           0  ...                   0          0.000000
# 7997                           0  ...                   0          0.000000
# 7998                 -2138963968  ...         -2138963968          0.000000
# 7999                           0  ...                   0          0.000000
#
#       Temp_product_out_qc  Temp_tunnel_measured  Temp_tunnel_measured_qc  \
# 0             -2138963968                   0.0              -2138963968
# 1                       0                 -86.0                        0
# 2             -2138963968                   0.0              -2138963968
# 3                       0                 -85.9                        0
# 4                       0                 -86.0                        0
# ...                   ...                   ...                      ...
# 7995                    0                  11.0                        0
# 7996                    0                  10.9                        0
# 7997                    0                  10.9                        0
# 7998          -2138963968                   0.0              -2138963968
# 7999                    0                  10.8                        0
#
#       Temp_tunnel_set  Temp_tunnel_set_qc  Vanne_opening_rate  \
# 0                   0         -2138963968            0.000000
# 1                 -86                   0           23.397518
# 2                   0         -2138963968            0.000000
# 3                 -86                   0           26.608585
# 4                 -86                   0           25.009882
# ...               ...                 ...                 ...
# 7995                0                   0            0.000000
# 7996                0                   0            0.000000
# 7997                0                   0            0.000000
# 7998                0         -2138963968            0.000000
# 7999                0                   0            0.000000
#
#       Vanne_opening_rate_qc                     _time
# 0               -2138963968  2020-09-10T10:16:48.242Z
# 1                         0  2020-09-10T10:17:48.286Z
# 2               -2138963968  2020-09-10T10:18:48.236Z
# 3                         0  2020-09-10T10:19:48.307Z
# 4                         0  2020-09-10T10:20:48.319Z
# ...                     ...                       ...
# 7995                      0  2020-09-16T00:02:30.776Z
# 7996                      0  2020-09-16T00:03:33.173Z
# 7997                      0  2020-09-16T00:04:32.412Z
# 7998            -2138963968  2020-09-16T00:05:32.680Z
# 7999                      0  2020-09-16T00:06:32.688Z
#
# [8000 rows x 51 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 51 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   BeltAmpere_belt1            8000 non-null   float64
#  1   BeltAmpere_belt1_qc         8000 non-null   int64
#  2   BeltAmpere_belt2            8000 non-null   float64
#  3   BeltAmpere_belt2_qc         8000 non-null   int64
#  4   BeltAmpere_belt3            8000 non-null   float64
#  5   BeltAmpere_belt3_qc         8000 non-null   int64
#  6   Cumulative_LIN_flow         8000 non-null   int64
#  7   Cumulative_LIN_flow_qc      8000 non-null   int64
#  8   Cumulative_product_flow     8000 non-null   int64
#  9   Cumulative_product_flow_qc  8000 non-null   int64
#  10  FanAmpere_exhaust1          8000 non-null   float64
#  11  FanAmpere_exhaust1_qc       8000 non-null   int64
#  12  FanAmpere_exhaust2          8000 non-null   float64
#  13  FanAmpere_exhaust2_qc       8000 non-null   int64
#  14  FanAmpere_side              8000 non-null   float64
#  15  FanAmpere_side_qc           8000 non-null   int64
#  16  FanAmpere_top               8000 non-null   float64
#  17  FanAmpere_top_qc            8000 non-null   int64
#  18  Fanspeed_exhaust1           8000 non-null   int64
#  19  Fanspeed_exhaust1_qc        8000 non-null   int64
#  20  Fanspeed_exhaust2           8000 non-null   int64
#  21  Fanspeed_exhaust2_qc        8000 non-null   int64
#  22  Fanspeed_side               8000 non-null   int64
#  23  Fanspeed_side_qc            8000 non-null   int64
#  24  Fanspeed_top                8000 non-null   int64
#  25  Fanspeed_top_qc             8000 non-null   int64
#  26  LIN_flow                    8000 non-null   float64
#  27  LIN_flow_qc                 8000 non-null   int64
#  28  Product_flow                8000 non-null   float64
#  29  Product_flow_qc             8000 non-null   int64
#  30  ResidenceTime_belt1         8000 non-null   int64
#  31  ResidenceTime_belt1_qc      8000 non-null   int64
#  32  ResidenceTime_belt2         8000 non-null   int64
#  33  ResidenceTime_belt2_qc      8000 non-null   int64
#  34  ResidenceTime_belt3         8000 non-null   int64
#  35  ResidenceTime_belt3_qc      8000 non-null   int64
#  36  Temp_exhaust_in             8000 non-null   float64
#  37  Temp_exhaust_in_qc          8000 non-null   int64
#  38  Temp_exhaust_out            8000 non-null   float64
#  39  Temp_exhaust_out_qc         8000 non-null   int64
#  40  Temp_product_in             8000 non-null   float64
#  41  Temp_product_in_qc          8000 non-null   int64
#  42  Temp_product_out            8000 non-null   float64
#  43  Temp_product_out_qc         8000 non-null   int64
#  44  Temp_tunnel_measured        8000 non-null   float64
#  45  Temp_tunnel_measured_qc     8000 non-null   int64
#  46  Temp_tunnel_set             8000 non-null   int64
#  47  Temp_tunnel_set_qc          8000 non-null   int64
#  48  Vanne_opening_rate          8000 non-null   float64
#  49  Vanne_opening_rate_qc       8000 non-null   int64
#  50  _time                       8000 non-null   object
# dtypes: float64(15), int64(35), object(1)
# memory usage: 3.1+ MB

# %%
df_all_short = df_all.iloc[:, ::2]
df_all_short
# Out:
#       BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# 0             0.000000          0.000000          0.000000
# 1             2.422485          3.634644          3.515625
# 2             0.000000          0.000000          0.000000
# 3             2.426758          3.676758          3.535156
# 4             2.426147          3.619385          3.523560
# ...                ...               ...               ...
# 7995          0.002441          0.002441          0.002441
# 7996          0.002441          0.002441          0.002441
# 7997          0.002441          0.001831          0.002441
# 7998          0.000000          0.000000          0.000000
# 7999          0.002441          0.002441          0.002441
#
#       Cumulative_LIN_flow  Cumulative_product_flow  FanAmpere_exhaust1  \
# 0                       0                        0            0.000000
# 1                  349032                   176026            2.134876
# 2                       0                        0            0.000000
# 3                  349060                   176047            2.151459
# 4                  349076                   176057            2.141422
# ...                   ...                      ...                 ...
# 7995               388352                   210730            3.036917
# 7996               388356                   210730            3.028189
# 7997               388359                   210730            3.033426
# 7998                    0                        0            0.000000
# 7999               388366                   210730            3.042154
#
#       FanAmpere_exhaust2  FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# 0               0.000000        0.000000       0.000000                  0
# 1               2.439484        8.004913       8.134003                 50
# 2               0.000000        0.000000       0.000000                  0
# 3               2.434683        8.000793       8.136749                 50
# 4               2.432938        7.995300       8.139496                 50
# ...                  ...             ...            ...                ...
# 7995            3.524378        0.000000       0.000000                100
# 7996            3.549689        0.000000       0.000000                100
# 7997            3.450189        0.000000       0.000000                100
# 7998            0.000000        0.000000       0.000000                  0
# 7999            3.552307        0.000000       0.000000                100
#
#       ...  ResidenceTime_belt2  ResidenceTime_belt3  Temp_exhaust_in  \
# 0     ...                    0                    0              0.0
# 1     ...                  150                  150             -1.9
# 2     ...                    0                    0              0.0
# 3     ...                  150                  150             -1.2
# 4     ...                  150                  150             -1.5
# ...   ...                  ...                  ...              ...
# 7995  ...                    0                    0             13.0
# 7996  ...                    0                    0             12.9
# 7997  ...                    0                    0             12.8
# 7998  ...                    0                    0              0.0
# 7999  ...                    0                    0             12.8
#
#       Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# 0                  0.0         0.000000          0.000000
# 1                  4.6        13.529578        -23.275791
# 2                  0.0         0.000000          0.000000
# 3                  5.0        13.726443          0.000000
# 4                  4.7        13.937914        -23.905650
# ...                ...              ...               ...
# 7995              12.4         0.000000          0.000000
# 7996              12.3         0.000000          0.000000
# 7997              12.3         0.000000          0.000000
# 7998               0.0         0.000000          0.000000
# 7999              12.2         0.000000          0.000000
#
#       Temp_tunnel_measured  Temp_tunnel_set  Vanne_opening_rate  \
# 0                      0.0                0            0.000000
# 1                    -86.0              -86           23.397518
# 2                      0.0                0            0.000000
# 3                    -85.9              -86           26.608585
# 4                    -86.0              -86           25.009882
# ...                    ...              ...                 ...
# 7995                  11.0                0            0.000000
# 7996                  10.9                0            0.000000
# 7997                  10.9                0            0.000000
# 7998                   0.0                0            0.000000
# 7999                  10.8                0            0.000000
#
#                          _time
# 0     2020-09-10T10:16:48.242Z
# 1     2020-09-10T10:17:48.286Z
# 2     2020-09-10T10:18:48.236Z
# 3     2020-09-10T10:19:48.307Z
# 4     2020-09-10T10:20:48.319Z
# ...                        ...
# 7995  2020-09-16T00:02:30.776Z
# 7996  2020-09-16T00:03:33.173Z
# 7997  2020-09-16T00:04:32.412Z
# 7998  2020-09-16T00:05:32.680Z
# 7999  2020-09-16T00:06:32.688Z
#
# [8000 rows x 26 columns]

# %%
df_all_short["_time"] = pd.to_datetime(df_all_short["_time"])

# %%
df_all_short
# Out:
#       BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# 0             0.000000          0.000000          0.000000
# 1             2.422485          3.634644          3.515625
# 2             0.000000          0.000000          0.000000
# 3             2.426758          3.676758          3.535156
# 4             2.426147          3.619385          3.523560
# ...                ...               ...               ...
# 7995          0.002441          0.002441          0.002441
# 7996          0.002441          0.002441          0.002441
# 7997          0.002441          0.001831          0.002441
# 7998          0.000000          0.000000          0.000000
# 7999          0.002441          0.002441          0.002441
#
#       Cumulative_LIN_flow  Cumulative_product_flow  FanAmpere_exhaust1  \
# 0                       0                        0            0.000000
# 1                  349032                   176026            2.134876
# 2                       0                        0            0.000000
# 3                  349060                   176047            2.151459
# 4                  349076                   176057            2.141422
# ...                   ...                      ...                 ...
# 7995               388352                   210730            3.036917
# 7996               388356                   210730            3.028189
# 7997               388359                   210730            3.033426
# 7998                    0                        0            0.000000
# 7999               388366                   210730            3.042154
#
#       FanAmpere_exhaust2  FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# 0               0.000000        0.000000       0.000000                  0
# 1               2.439484        8.004913       8.134003                 50
# 2               0.000000        0.000000       0.000000                  0
# 3               2.434683        8.000793       8.136749                 50
# 4               2.432938        7.995300       8.139496                 50
# ...                  ...             ...            ...                ...
# 7995            3.524378        0.000000       0.000000                100
# 7996            3.549689        0.000000       0.000000                100
# 7997            3.450189        0.000000       0.000000                100
# 7998            0.000000        0.000000       0.000000                  0
# 7999            3.552307        0.000000       0.000000                100
#
#       ...  ResidenceTime_belt2  ResidenceTime_belt3  Temp_exhaust_in  \
# 0     ...                    0                    0              0.0
# 1     ...                  150                  150             -1.9
# 2     ...                    0                    0              0.0
# 3     ...                  150                  150             -1.2
# 4     ...                  150                  150             -1.5
# ...   ...                  ...                  ...              ...
# 7995  ...                    0                    0             13.0
# 7996  ...                    0                    0             12.9
# 7997  ...                    0                    0             12.8
# 7998  ...                    0                    0              0.0
# 7999  ...                    0                    0             12.8
#
#       Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# 0                  0.0         0.000000          0.000000
# 1                  4.6        13.529578        -23.275791
# 2                  0.0         0.000000          0.000000
# 3                  5.0        13.726443          0.000000
# 4                  4.7        13.937914        -23.905650
# ...                ...              ...               ...
# 7995              12.4         0.000000          0.000000
# 7996              12.3         0.000000          0.000000
# 7997              12.3         0.000000          0.000000
# 7998               0.0         0.000000          0.000000
# 7999              12.2         0.000000          0.000000
#
#       Temp_tunnel_measured  Temp_tunnel_set  Vanne_opening_rate  \
# 0                      0.0                0            0.000000
# 1                    -86.0              -86           23.397518
# 2                      0.0                0            0.000000
# 3                    -85.9              -86           26.608585
# 4                    -86.0              -86           25.009882
# ...                    ...              ...                 ...
# 7995                  11.0                0            0.000000
# 7996                  10.9                0            0.000000
# 7997                  10.9                0            0.000000
# 7998                   0.0                0            0.000000
# 7999                  10.8                0            0.000000
#
#                                 _time
# 0    2020-09-10 10:16:48.242000+00:00
# 1    2020-09-10 10:17:48.286000+00:00
# 2    2020-09-10 10:18:48.236000+00:00
# 3    2020-09-10 10:19:48.307000+00:00
# 4    2020-09-10 10:20:48.319000+00:00
# ...                               ...
# 7995 2020-09-16 00:02:30.776000+00:00
# 7996 2020-09-16 00:03:33.173000+00:00
# 7997 2020-09-16 00:04:32.412000+00:00
# 7998 2020-09-16 00:05:32.680000+00:00
# 7999 2020-09-16 00:06:32.688000+00:00
#
# [8000 rows x 26 columns]

# %%
df_all_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   BeltAmpere_belt1         8000 non-null   float64
#  1   BeltAmpere_belt2         8000 non-null   float64
#  2   BeltAmpere_belt3         8000 non-null   float64
#  3   Cumulative_LIN_flow      8000 non-null   int64
#  4   Cumulative_product_flow  8000 non-null   int64
#  5   FanAmpere_exhaust1       8000 non-null   float64
#  6   FanAmpere_exhaust2       8000 non-null   float64
#  7   FanAmpere_side           8000 non-null   float64
#  8   FanAmpere_top            8000 non-null   float64
#  9   Fanspeed_exhaust1        8000 non-null   int64
#  10  Fanspeed_exhaust2        8000 non-null   int64
#  11  Fanspeed_side            8000 non-null   int64
#  12  Fanspeed_top             8000 non-null   int64
#  13  LIN_flow                 8000 non-null   float64
#  14  Product_flow             8000 non-null   float64
#  15  ResidenceTime_belt1      8000 non-null   int64
#  16  ResidenceTime_belt2      8000 non-null   int64
#  17  ResidenceTime_belt3      8000 non-null   int64
#  18  Temp_exhaust_in          8000 non-null   float64
#  19  Temp_exhaust_out         8000 non-null   float64
#  20  Temp_product_in          8000 non-null   float64
#  21  Temp_product_out         8000 non-null   float64
#  22  Temp_tunnel_measured     8000 non-null   float64
#  23  Temp_tunnel_set          8000 non-null   int64
#  24  Vanne_opening_rate       8000 non-null   float64
#  25  _time                    8000 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(15), int64(10)
# memory usage: 1.6 MB

# %%
x_time = df_all_short["_time"]
y_LIN = df_all_short["LIN_flow"]
y_PROD = df_all_short["Product_flow"]

# %%
plt.figure(figsize=(35, 35))
ax = plt.subplot(3,3,3)
plt.plot(x_time, y_LIN, color="red", label="LIN_flow")
plt.plot(x_time, y_PROD, color="black", label="Product_flow", alpha=0.5)
plt.xlabel("Time")
plt.ylabel("LIN_flow")
plt.grid(True)
plt.legend()

# %%
df_w_o_prod_flow = df_all_short[df_all_short["Product_flow"] >= 1.175381e-33]

# %%
df_w_o_prod_flow = df_w_o_prod_flow[df_all_short["Product_flow"] != 0]

# %%
df_w_o_prod_flow.shape
# Out:
# (1296, 26)

# %%
df_w_o_prod_flow.reset_index(inplace=True, drop=True)

# %%
df_w_o_prod_flow
# Out:
#       BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# 0             2.422485          3.634644          3.515625
# 1             2.426758          3.676758          3.535156
# 2             2.426147          3.619385          3.523560
# 3             2.421265          3.651123          3.517456
# 4             2.418213          3.659058          3.558350
# ...                ...               ...               ...
# 1291          0.000000          0.000000          0.000000
# 1292          0.000000          0.000000          0.000000
# 1293          0.000000          0.000000          0.000000
# 1294          0.000000          0.000000          0.000000
# 1295          0.000000          0.000000          0.000000
#
#       Cumulative_LIN_flow  Cumulative_product_flow  FanAmpere_exhaust1  \
# 0                  349032                   176026            2.134876
# 1                  349060                   176047            2.151459
# 2                  349076                   176057            2.141422
# 3                  349105                   176079            2.140549
# 4                  349136                   176105            2.149277
# ...                   ...                      ...                 ...
# 1291               379598                   210730            2.952255
# 1292               379598                   210730            2.935672
# 1293               379598                   210730            2.948328
# 1294               379598                   210730            2.967966
# 1295               379598                   210730            2.948328
#
#       FanAmpere_exhaust2  FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# 0               2.439484        8.004913       8.134003                 50
# 1               2.434683        8.000793       8.136749                 50
# 2               2.432938        7.995300       8.139496                 50
# 3               2.442975        8.009033       8.123016                 50
# 4               2.442975        8.006287       8.134003                 50
# ...                  ...             ...            ...                ...
# 1291            3.373383        0.000000       0.000000                100
# 1292            3.381674        0.000000       0.000000                100
# 1293            3.417023        0.000000       0.000000                100
# 1294            3.427496        0.000000       0.000000                100
# 1295            3.417896        0.000000       0.000000                100
#
#       ...  ResidenceTime_belt2  ResidenceTime_belt3  Temp_exhaust_in  \
# 0     ...                  150                  150             -1.9
# 1     ...                  150                  150             -1.2
# 2     ...                  150                  150             -1.5
# 3     ...                  150                  150             -2.8
# 4     ...                  150                  150             -3.3
# ...   ...                  ...                  ...              ...
# 1291  ...                    0                    0             13.7
# 1292  ...                    0                    0             13.1
# 1293  ...                    0                    0             12.7
# 1294  ...                    0                    0             11.4
# 1295  ...                    0                    0             10.7
#
#       Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# 0                  4.6        13.529578        -23.275791
# 1                  5.0        13.726443          0.000000
# 2                  4.7        13.937914        -23.905650
# 3                  4.6        14.087171          0.000000
# 4                  4.1        14.165814        -23.897295
# ...                ...              ...               ...
# 1291              12.9         0.000000          0.000000
# 1292              12.7         0.000000          0.000000
# 1293              11.9         0.000000          0.000000
# 1294              11.1         0.000000          0.000000
# 1295              10.7         0.000000          0.000000
#
#       Temp_tunnel_measured  Temp_tunnel_set  Vanne_opening_rate  \
# 0                    -86.0              -86           23.397518
# 1                    -85.9              -86           26.608585
# 2                    -86.0              -86           25.009882
# 3                    -86.0              -86           26.686907
# 4                    -86.0              -86           26.132190
# ...                    ...              ...                 ...
# 1291                  10.4                0            0.000000
# 1292                  10.5                0            0.000000
# 1293                  10.2                0            0.000000
# 1294                   9.5                0            0.000000
# 1295                   9.0                0            0.000000
#
#                                 _time
# 0    2020-09-10 10:17:48.286000+00:00
# 1    2020-09-10 10:19:48.307000+00:00
# 2    2020-09-10 10:20:48.319000+00:00
# 3    2020-09-10 10:22:48.317000+00:00
# 4    2020-09-10 10:24:48.333000+00:00
# ...                               ...
# 1291 2020-09-11 19:51:07.777000+00:00
# 1292 2020-09-11 19:53:07.803000+00:00
# 1293 2020-09-11 19:54:07.780000+00:00
# 1294 2020-09-11 19:56:07.791000+00:00
# 1295 2020-09-11 19:58:07.799000+00:00
#
# [1296 rows x 26 columns]

# %%
df_w_o_prod_flow[["LIN_flow", "Product_flow", "Cumulative_LIN_flow", "Cumulative_product_flow", "_time"]].head()
# Out:
#     LIN_flow  Product_flow  Cumulative_LIN_flow  Cumulative_product_flow  \
# 0  837.65880     608.69820               349032                   176026
# 1  829.37560     641.16327               349060                   176047
# 2  864.51056     622.50900               349076                   176057
# 3  873.10240     657.43910               349105                   176079
# 4  912.19214     734.82574               349136                   176105
#
#                              _time
# 0 2020-09-10 10:17:48.286000+00:00
# 1 2020-09-10 10:19:48.307000+00:00
# 2 2020-09-10 10:20:48.319000+00:00
# 3 2020-09-10 10:22:48.317000+00:00
# 4 2020-09-10 10:24:48.333000+00:00

# %%
df_w_o_prod_flow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   BeltAmpere_belt1         1296 non-null   float64
#  1   BeltAmpere_belt2         1296 non-null   float64
#  2   BeltAmpere_belt3         1296 non-null   float64
#  3   Cumulative_LIN_flow      1296 non-null   int64
#  4   Cumulative_product_flow  1296 non-null   int64
#  5   FanAmpere_exhaust1       1296 non-null   float64
#  6   FanAmpere_exhaust2       1296 non-null   float64
#  7   FanAmpere_side           1296 non-null   float64
#  8   FanAmpere_top            1296 non-null   float64
#  9   Fanspeed_exhaust1        1296 non-null   int64
#  10  Fanspeed_exhaust2        1296 non-null   int64
#  11  Fanspeed_side            1296 non-null   int64
#  12  Fanspeed_top             1296 non-null   int64
#  13  LIN_flow                 1296 non-null   float64
#  14  Product_flow             1296 non-null   float64
#  15  ResidenceTime_belt1      1296 non-null   int64
#  16  ResidenceTime_belt2      1296 non-null   int64
#  17  ResidenceTime_belt3      1296 non-null   int64
#  18  Temp_exhaust_in          1296 non-null   float64
#  19  Temp_exhaust_out         1296 non-null   float64
#  20  Temp_product_in          1296 non-null   float64
#  21  Temp_product_out         1296 non-null   float64
#  22  Temp_tunnel_measured     1296 non-null   float64
#  23  Temp_tunnel_set          1296 non-null   int64
#  24  Vanne_opening_rate       1296 non-null   float64
#  25  _time                    1296 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(15), int64(10)
# memory usage: 263.4 KB

# %%
x_time = df_w_o_prod_flow["_time"]
y_LIN = df_w_o_prod_flow["LIN_flow"]
y_PROD = df_w_o_prod_flow["Product_flow"]

# %%
plt.figure(figsize=(35, 35))
ax = plt.subplot(3,3,3)
plt.plot(x_time, y_LIN, color="red", label="LIN_flow")
plt.plot(x_time, y_PROD, color="black", label="Product_flow", alpha=0.5)
plt.xlabel("Time")
plt.ylabel("LIN_flow")
plt.grid(True)
plt.legend()

# %%
df_w_o_prod_flow.describe()
named_cols = df_w_o_prod_flow.columns[:-1]
named_cols
# Out:
# Index(['BeltAmpere_belt1', 'BeltAmpere_belt2', 'BeltAmpere_belt3',
#        'Cumulative_LIN_flow', 'Cumulative_product_flow', 'FanAmpere_exhaust1',
#        'FanAmpere_exhaust2', 'FanAmpere_side', 'FanAmpere_top',
#        'Fanspeed_exhaust1', 'Fanspeed_exhaust2', 'Fanspeed_side',
#        'Fanspeed_top', 'LIN_flow', 'Product_flow', 'ResidenceTime_belt1',
#        'ResidenceTime_belt2', 'ResidenceTime_belt3', 'Temp_exhaust_in',
#        'Temp_exhaust_out', 'Temp_product_in', 'Temp_product_out',
#        'Temp_tunnel_measured', 'Temp_tunnel_set', 'Vanne_opening_rate'],
#       dtype='object')

# %%
#Данные чистые, пустых значений нет
df_w_o_prod_flow.isnull().values.any()
df_w_o_prod_flow["_time"] = pd.to_datetime(df_w_o_prod_flow["_time"])

# %%
y = df_w_o_prod_flow["LIN_flow"]
x = df_w_o_prod_flow

# %%
print('Матрица корреляций всех признаков, кроме последнего:\n', x.iloc[:, :-1].corr())
print('\n')

print(x.shape)
# Out:
# Матрица корреляций всех признаков, кроме последнего:
#                           BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# BeltAmpere_belt1                 1.000000          0.869005          0.865164
# BeltAmpere_belt2                 0.869005          1.000000          0.996014
# BeltAmpere_belt3                 0.865164          0.996014          1.000000
# Cumulative_LIN_flow             -0.099683         -0.369642         -0.351575
# Cumulative_product_flow         -0.096020         -0.364332         -0.346208
# FanAmpere_exhaust1              -0.155690         -0.333231         -0.328116
# FanAmpere_exhaust2              -0.192915         -0.370881         -0.369075
# FanAmpere_side                   0.502739          0.788769          0.796168
# FanAmpere_top                    0.500717          0.788663          0.795927
# Fanspeed_exhaust1               -0.110576         -0.317998         -0.311924
# Fanspeed_exhaust2               -0.117923         -0.301694         -0.296224
# Fanspeed_side                    0.502454          0.788655          0.796083
# Fanspeed_top                     0.500083          0.785268          0.792731
# LIN_flow                         0.323746          0.488099          0.488009
# Product_flow                     0.349993          0.489345          0.487679
# ResidenceTime_belt1              0.887999          0.938451          0.943034
# ResidenceTime_belt2              0.906648          0.930326          0.921580
# ResidenceTime_belt3              0.906648          0.930326          0.921580
# Temp_exhaust_in                  0.011686         -0.231715         -0.217858
# Temp_exhaust_out                -0.259364         -0.392441         -0.389033
# Temp_product_in                  0.451736          0.483710          0.484260
# Temp_product_out                -0.292476         -0.406936         -0.405664
# Temp_tunnel_measured            -0.607136         -0.883831         -0.882474
# Temp_tunnel_set                 -0.417804         -0.765322         -0.767208
# Vanne_opening_rate               0.210470          0.394670          0.392677
#
#                          Cumulative_LIN_flow  Cumulative_product_flow  \
# BeltAmpere_belt1                   -0.099683                -0.096020
# BeltAmpere_belt2                   -0.369642                -0.364332
# BeltAmpere_belt3                   -0.351575                -0.346208
# Cumulative_LIN_flow                 1.000000                 0.999334
# Cumulative_product_flow             0.999334                 1.000000
# FanAmpere_exhaust1                  0.513089                 0.514059
# FanAmpere_exhaust2                  0.481472                 0.481263
# FanAmpere_side                     -0.368895                -0.364550
# FanAmpere_top                      -0.371542                -0.367205
# Fanspeed_exhaust1                   0.570782                 0.572649
# Fanspeed_exhaust2                   0.530424                 0.532340
# Fanspeed_side                      -0.369073                -0.364730
# Fanspeed_top                       -0.367816                -0.363497
# LIN_flow                           -0.225153                -0.214932
# Product_flow                       -0.324906                -0.317376
# ResidenceTime_belt1                -0.202067                -0.197603
# ResidenceTime_belt2                -0.271923                -0.266275
# ResidenceTime_belt3                -0.271923                -0.266275
# Temp_exhaust_in                     0.679220                 0.682238
# Temp_exhaust_out                    0.129255                 0.125544
# Temp_product_in                    -0.042335                -0.026973
# Temp_product_out                    0.074193                 0.065152
# Temp_tunnel_measured                0.527302                 0.521417
# Temp_tunnel_set                     0.512191                 0.506849
# Vanne_opening_rate                 -0.342920                -0.335050
#
#                          FanAmpere_exhaust1  FanAmpere_exhaust2  \
# BeltAmpere_belt1                  -0.155690           -0.192915
# BeltAmpere_belt2                  -0.333231           -0.370881
# BeltAmpere_belt3                  -0.328116           -0.369075
# Cumulative_LIN_flow                0.513089            0.481472
# Cumulative_product_flow            0.514059            0.481263
# FanAmpere_exhaust1                 1.000000            0.975581
# FanAmpere_exhaust2                 0.975581            1.000000
# FanAmpere_side                    -0.249628           -0.293655
# FanAmpere_top                     -0.251908           -0.295487
# Fanspeed_exhaust1                  0.953262            0.936665
# Fanspeed_exhaust2                  0.984428            0.968522
# Fanspeed_side                     -0.250204           -0.293896
# Fanspeed_top                      -0.254996           -0.299006
# LIN_flow                          -0.053248           -0.091156
# Product_flow                      -0.128610           -0.156413
# ResidenceTime_belt1               -0.243714           -0.295163
# ResidenceTime_belt2               -0.263299           -0.291717
# ResidenceTime_belt3               -0.263299           -0.291717
# Temp_exhaust_in                    0.395407            0.388840
# Temp_exhaust_out                   0.301687            0.321745
# Temp_product_in                    0.084789            0.041082
# Temp_product_out                   0.080094            0.121210
# Temp_tunnel_measured               0.355273            0.387522
# Temp_tunnel_set                    0.338643            0.370560
# Vanne_opening_rate                -0.097857           -0.087801
#
#                          FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# BeltAmpere_belt1               0.502739       0.500717          -0.110576
# BeltAmpere_belt2               0.788769       0.788663          -0.317998
# BeltAmpere_belt3               0.796168       0.795927          -0.311924
# Cumulative_LIN_flow           -0.368895      -0.371542           0.570782
# Cumulative_product_flow       -0.364550      -0.367205           0.572649
# FanAmpere_exhaust1            -0.249628      -0.251908           0.953262
# FanAmpere_exhaust2            -0.293655      -0.295487           0.936665
# FanAmpere_side                 1.000000       0.999883          -0.302796
# FanAmpere_top                  0.999883       1.000000          -0.305611
# Fanspeed_exhaust1             -0.302796      -0.305611           1.000000
# Fanspeed_exhaust2             -0.235241      -0.237867           0.981960
# Fanspeed_side                  0.999842       0.999708          -0.303595
# Fanspeed_top                   0.995693       0.995240          -0.306153
# LIN_flow                       0.525570       0.526845          -0.062762
# Product_flow                   0.557175       0.554210          -0.150665
# ResidenceTime_belt1            0.788382       0.786457          -0.209532
# ResidenceTime_belt2            0.592138       0.592593          -0.246379
# ResidenceTime_belt3            0.592138       0.592593          -0.246379
# Temp_exhaust_in               -0.235862      -0.240079           0.479059
# Temp_exhaust_out              -0.412489      -0.415040           0.324374
# Temp_product_in                0.394567       0.390348           0.134455
# Temp_product_out              -0.397272      -0.395957           0.065253
# Temp_tunnel_measured          -0.876073      -0.877791           0.395515
# Temp_tunnel_set               -0.963703      -0.965600           0.401941
# Vanne_opening_rate             0.480384       0.484591          -0.137166
#
#                          ...  ResidenceTime_belt1  ResidenceTime_belt2  \
# BeltAmpere_belt1         ...             0.887999             0.906648
# BeltAmpere_belt2         ...             0.938451             0.930326
# BeltAmpere_belt3         ...             0.943034             0.921580
# Cumulative_LIN_flow      ...            -0.202067            -0.271923
# Cumulative_product_flow  ...            -0.197603            -0.266275
# FanAmpere_exhaust1       ...            -0.243714            -0.263299
# FanAmpere_exhaust2       ...            -0.295163            -0.291717
# FanAmpere_side           ...             0.788382             0.592138
# FanAmpere_top            ...             0.786457             0.592593
# Fanspeed_exhaust1        ...            -0.209532            -0.246379
# Fanspeed_exhaust2        ...            -0.201033            -0.235507
# Fanspeed_side            ...             0.788088             0.592027
# Fanspeed_top             ...             0.784541             0.589998
# LIN_flow                 ...             0.444830             0.398472
# Product_flow             ...             0.496430             0.361844
# ResidenceTime_belt1      ...             1.000000             0.825378
# ResidenceTime_belt2      ...             0.825378             1.000000
# ResidenceTime_belt3      ...             0.825378             1.000000
# Temp_exhaust_in          ...            -0.051373            -0.191640
# Temp_exhaust_out         ...            -0.350991            -0.352217
# Temp_product_in          ...             0.505572             0.427381
# Temp_product_out         ...            -0.405926            -0.318617
# Temp_tunnel_measured     ...            -0.796358            -0.739524
# Temp_tunnel_set          ...            -0.697658            -0.587761
# Vanne_opening_rate       ...             0.347973             0.285656
#
#                          ResidenceTime_belt3  Temp_exhaust_in  \
# BeltAmpere_belt1                    0.906648         0.011686
# BeltAmpere_belt2                    0.930326        -0.231715
# BeltAmpere_belt3                    0.921580        -0.217858
# Cumulative_LIN_flow                -0.271923         0.679220
# Cumulative_product_flow            -0.266275         0.682238
# FanAmpere_exhaust1                 -0.263299         0.395407
# FanAmpere_exhaust2                 -0.291717         0.388840
# FanAmpere_side                      0.592138        -0.235862
# FanAmpere_top                       0.592593        -0.240079
# Fanspeed_exhaust1                  -0.246379         0.479059
# Fanspeed_exhaust2                  -0.235507         0.441687
# Fanspeed_side                       0.592027        -0.236073
# Fanspeed_top                        0.589998        -0.233732
# LIN_flow                            0.398472        -0.305465
# Product_flow                        0.361844        -0.302958
# ResidenceTime_belt1                 0.825378        -0.051373
# ResidenceTime_belt2                 1.000000        -0.191640
# ResidenceTime_belt3                 1.000000        -0.191640
# Temp_exhaust_in                    -0.191640         1.000000
# Temp_exhaust_out                   -0.352217         0.155013
# Temp_product_in                     0.427381         0.033122
# Temp_product_out                   -0.318617         0.061681
# Temp_tunnel_measured               -0.739524         0.384312
# Temp_tunnel_set                    -0.587761         0.370148
# Vanne_opening_rate                  0.285656        -0.170809
#
#                          Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# BeltAmpere_belt1                -0.259364         0.451736         -0.292476
# BeltAmpere_belt2                -0.392441         0.483710         -0.406936
# BeltAmpere_belt3                -0.389033         0.484260         -0.405664
# Cumulative_LIN_flow              0.129255        -0.042335          0.074193
# Cumulative_product_flow          0.125544        -0.026973          0.065152
# FanAmpere_exhaust1               0.301687         0.084789          0.080094
# FanAmpere_exhaust2               0.321745         0.041082          0.121210
# FanAmpere_side                  -0.412489         0.394567         -0.397272
# FanAmpere_top                   -0.415040         0.390348         -0.395957
# Fanspeed_exhaust1                0.324374         0.134455          0.065253
# Fanspeed_exhaust2                0.289823         0.132814          0.052233
# Fanspeed_side                   -0.413273         0.393891         -0.397133
# Fanspeed_top                    -0.414116         0.391220         -0.398174
# LIN_flow                        -0.423138         0.760631         -0.587322
# Product_flow                    -0.342729         0.639520         -0.490343
# ResidenceTime_belt1             -0.350991         0.505572         -0.405926
# ResidenceTime_belt2             -0.352217         0.427381         -0.318617
# ResidenceTime_belt3             -0.352217         0.427381         -0.318617
# Temp_exhaust_in                  0.155013         0.033122          0.061681
# Temp_exhaust_out                 1.000000        -0.270336          0.556262
# Temp_product_in                 -0.270336         1.000000         -0.594547
# Temp_product_out                 0.556262        -0.594547          1.000000
# Temp_tunnel_measured             0.501769        -0.367524          0.433302
# Temp_tunnel_set                  0.468340        -0.318980          0.392561
# Vanne_opening_rate              -0.153742         0.390022         -0.304659
#
#                          Temp_tunnel_measured  Temp_tunnel_set  \
# BeltAmpere_belt1                    -0.607136        -0.417804
# BeltAmpere_belt2                    -0.883831        -0.765322
# BeltAmpere_belt3                    -0.882474        -0.767208
# Cumulative_LIN_flow                  0.527302         0.512191
# Cumulative_product_flow              0.521417         0.506849
# FanAmpere_exhaust1                   0.355273         0.338643
# FanAmpere_exhaust2                   0.387522         0.370560
# FanAmpere_side                      -0.876073        -0.963703
# FanAmpere_top                       -0.877791        -0.965600
# Fanspeed_exhaust1                    0.395515         0.401941
# Fanspeed_exhaust2                    0.338160         0.330684
# Fanspeed_side                       -0.876313        -0.964002
# Fanspeed_top                        -0.877101        -0.960567
# LIN_flow                            -0.522497        -0.516539
# Product_flow                        -0.507174        -0.520523
# ResidenceTime_belt1                 -0.796358        -0.697658
# ResidenceTime_belt2                 -0.739524        -0.587761
# ResidenceTime_belt3                 -0.739524        -0.587761
# Temp_exhaust_in                      0.384312         0.370148
# Temp_exhaust_out                     0.501769         0.468340
# Temp_product_in                     -0.367524        -0.318980
# Temp_product_out                     0.433302         0.392561
# Temp_tunnel_measured                 1.000000         0.920025
# Temp_tunnel_set                      0.920025         1.000000
# Vanne_opening_rate                  -0.415443        -0.497874
#
#                          Vanne_opening_rate
# BeltAmpere_belt1                   0.210470
# BeltAmpere_belt2                   0.394670
# BeltAmpere_belt3                   0.392677
# Cumulative_LIN_flow               -0.342920
# Cumulative_product_flow           -0.335050
# FanAmpere_exhaust1                -0.097857
# FanAmpere_exhaust2                -0.087801
# FanAmpere_side                     0.480384
# FanAmpere_top                      0.484591
# Fanspeed_exhaust1                 -0.137166
# Fanspeed_exhaust2                 -0.103406
# Fanspeed_side                      0.481326
# Fanspeed_top                       0.461395
# LIN_flow                           0.454430
# Product_flow                       0.461263
# ResidenceTime_belt1                0.347973
# ResidenceTime_belt2                0.285656
# ResidenceTime_belt3                0.285656
# Temp_exhaust_in                   -0.170809
# Temp_exhaust_out                  -0.153742
# Temp_product_in                    0.390022
# Temp_product_out                  -0.304659
# Temp_tunnel_measured              -0.415443
# Temp_tunnel_set                   -0.497874
# Vanne_opening_rate                 1.000000
#
# [25 rows x 25 columns]
#
#
# (1296, 26)

# %%
corr_ = x.corrwith(y, method='spearman')
sa = dict(corr_).items()
sorted(sa, key = lambda x : x[1])
# Out:
# [('Temp_product_out', -0.44599404862661557),
#  ('Temp_exhaust_out', -0.3583108664325749),
#  ('Temp_tunnel_set', -0.295130121490927),
#  ('Temp_exhaust_in', -0.28168021605494536),
#  ('Temp_tunnel_measured', -0.2773754144597045),
#  ('Cumulative_LIN_flow', -0.19711694391766582),
#  ('Cumulative_product_flow', -0.19668508617606856),
#  ('FanAmpere_exhaust2', -0.14907143393261826),
#  ('Fanspeed_exhaust1', -0.06283628277437485),
#  ('Fanspeed_exhaust2', -0.061094339158799194),
#  ('FanAmpere_exhaust1', -0.04910676124945409),
#  ('ResidenceTime_belt1', 0.01844929219287065),
#  ('BeltAmpere_belt1', 0.04459521673712781),
#  ('FanAmpere_side', 0.21609804492910276),
#  ('BeltAmpere_belt2', 0.23322884479550848),
#  ('BeltAmpere_belt3', 0.2348104835812842),
#  ('ResidenceTime_belt2', 0.3168839377430077),
#  ('ResidenceTime_belt3', 0.3168839377430077),
#  ('Vanne_opening_rate', 0.348736135489225),
#  ('FanAmpere_top', 0.38767728340819335),
#  ('Fanspeed_top', 0.393021627331777),
#  ('Fanspeed_side', 0.4038996292989294),
#  ('Temp_product_in', 0.4774326110637231),
#  ('Product_flow', 0.5366787869486406),
#  ('LIN_flow', 1.0)]

# %%
x[['Temp_exhaust_out', 'Temp_product_in', 'Temp_tunnel_set', 'Temp_exhaust_in', 'BeltAmpere_belt2', 'LIN_flow']].corr()
# Out:
#                   Temp_exhaust_out  Temp_product_in  Temp_tunnel_set  \
# Temp_exhaust_out          1.000000        -0.270336         0.468340
# Temp_product_in          -0.270336         1.000000        -0.318980
# Temp_tunnel_set           0.468340        -0.318980         1.000000
# Temp_exhaust_in           0.155013         0.033122         0.370148
# BeltAmpere_belt2         -0.392441         0.483710        -0.765322
# LIN_flow                 -0.423138         0.760631        -0.516539
#
#                   Temp_exhaust_in  BeltAmpere_belt2  LIN_flow
# Temp_exhaust_out         0.155013         -0.392441 -0.423138
# Temp_product_in          0.033122          0.483710  0.760631
# Temp_tunnel_set          0.370148         -0.765322 -0.516539
# Temp_exhaust_in          1.000000         -0.231715 -0.305465
# BeltAmpere_belt2        -0.231715          1.000000  0.488099
# LIN_flow                -0.305465          0.488099  1.000000

# %%
plt.figure(figsize=(25, 25))
sns.heatmap(x[::].corr(), square=True, annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(nrows=9, ncols=3, figsize=(20, 65))
colormap = ["red", "green", "blue"]
for idx, feature in enumerate(x.columns[:-1]):
    x.plot(feature, "LIN_flow", subplots=True, kind="scatter", 
           ax=axes[idx // 3, idx % 3], color=colormap[idx % 3], grid=True)

# %%
x.hist(figsize=(20, 35), bins=100);

# %%
x.mean()
# Out:
# BeltAmpere_belt1                2.229233
# BeltAmpere_belt2                3.434863
# BeltAmpere_belt3                3.346588
# Cumulative_LIN_flow        365565.163580
# Cumulative_product_flow    195286.381944
# FanAmpere_exhaust1              2.374602
# FanAmpere_exhaust2              2.667903
# FanAmpere_side                  7.424516
# FanAmpere_top                   7.561594
# Fanspeed_exhaust1              66.419753
# Fanspeed_exhaust2              79.645062
# Fanspeed_side                  37.098765
# Fanspeed_top                   64.830247
# LIN_flow                      906.043444
# Product_flow                 1025.280763
# ResidenceTime_belt1            72.943673
# ResidenceTime_belt2           152.253086
# ResidenceTime_belt3           152.253086
# Temp_exhaust_in                 2.779475
# Temp_exhaust_out                1.117747
# Temp_product_in                13.889928
# Temp_product_out              -19.003880
# Temp_tunnel_measured          -85.332022
# Temp_tunnel_set               -84.290123
# Vanne_opening_rate             27.539256
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler, scale
from sklearn.utils import shuffle
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x.iloc[:, :-1])

# %%
x_scaled = pd.DataFrame(x_scaled, columns=named_cols)
x_scaled.hist(figsize=(20, 35), bins=100);

# %%
x_scaled
# Out:
#       BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# 0             0.349017          0.265759          0.230505
# 1             0.356733          0.321781          0.257138
# 2             0.355630          0.245461          0.241325
# 3             0.346812          0.287681          0.233002
# 4             0.341301          0.298236          0.288766
# ...                ...               ...               ...
# 1291         -4.026033         -4.569241         -4.563535
# 1292         -4.026033         -4.569241         -4.563535
# 1293         -4.026033         -4.569241         -4.563535
# 1294         -4.026033         -4.569241         -4.563535
# 1295         -4.026033         -4.569241         -4.563535
#
#       Cumulative_LIN_flow  Cumulative_product_flow  FanAmpere_exhaust1  \
# 0               -1.818885                -1.892824           -0.606510
# 1               -1.815805                -1.890761           -0.564555
# 2               -1.814045                -1.889778           -0.589949
# 3               -1.810854                -1.887616           -0.592157
# 4               -1.807444                -1.885061           -0.570075
# ...                   ...                      ...                 ...
# 1291             1.543813                 1.517730            1.461466
# 1292             1.543813                 1.517730            1.419510
# 1293             1.543813                 1.517730            1.451529
# 1294             1.543813                 1.517730            1.501214
# 1295             1.543813                 1.517730            1.451529
#
#       FanAmpere_exhaust2  FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# 0              -0.514512        0.279572       0.270689          -0.682107
# 1              -0.525325        0.277588       0.271988          -0.682107
# 2              -0.529257        0.274942       0.273287          -0.682107
# 3              -0.506649        0.281557       0.265493          -0.682107
# 4              -0.506649        0.280234       0.270689          -0.682107
# ...                  ...             ...            ...                ...
# 1291            1.589085       -3.576323      -3.575834           1.394986
# 1292            1.607762       -3.576323      -3.575834           1.394986
# 1293            1.687384       -3.576323      -3.575834           1.394986
# 1294            1.710976       -3.576323      -3.575834           1.394986
# 1295            1.689350       -3.576323      -3.575834           1.394986
#
#       ...  ResidenceTime_belt1  ResidenceTime_belt2  ResidenceTime_belt3  \
# 0     ...             0.417087            -0.063402            -0.063402
# 1     ...             0.417087            -0.063402            -0.063402
# 2     ...             0.417087            -0.063402            -0.063402
# 3     ...             0.417087            -0.063402            -0.063402
# 4     ...             0.417087            -0.063402            -0.063402
# ...   ...                  ...                  ...                  ...
# 1291  ...            -4.311570            -4.284445            -4.284445
# 1292  ...            -4.311570            -4.284445            -4.284445
# 1293  ...            -4.311570            -4.284445            -4.284445
# 1294  ...            -4.311570            -4.284445            -4.284445
# 1295  ...            -4.311570            -4.284445            -4.284445
#
#       Temp_exhaust_in  Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# 0           -0.614349          0.677099        -0.061659         -0.426505
# 1           -0.522449          0.754876        -0.027974          1.897336
# 2           -0.561834          0.696544         0.008211         -0.489390
# 3           -0.732506          0.677099         0.033750          1.897336
# 4           -0.798149          0.579878         0.047206         -0.488556
# ...               ...               ...              ...               ...
# 1291         1.433710          2.290975        -2.376683          1.897336
# 1292         1.354938          2.252087        -2.376683          1.897336
# 1293         1.302424          2.096532        -2.376683          1.897336
# 1294         1.131753          1.940978        -2.376683          1.897336
# 1295         1.039853          1.863201        -2.376683          1.897336
#
#       Temp_tunnel_measured  Temp_tunnel_set  Vanne_opening_rate
# 0                -0.029205        -0.069929           -0.258856
# 1                -0.024833        -0.069929           -0.058166
# 2                -0.029205        -0.069929           -0.158084
# 3                -0.029205        -0.069929           -0.053271
# 4                -0.029205        -0.069929           -0.087941
# ...                    ...              ...                 ...
# 1291              4.185548         3.447198           -1.721184
# 1292              4.189921         3.447198           -1.721184
# 1293              4.176804         3.447198           -1.721184
# 1294              4.146199         3.447198           -1.721184
# 1295              4.124338         3.447198           -1.721184
#
# [1296 rows x 25 columns]

# %%
plt.figure(figsize=(20, 55))
for i, feature in enumerate(x_scaled.columns):
    plt.subplot(9, 3, i+1)
    sns.kdeplot(x[feature])
    plt.xlabel(feature)
plt.show()

# %%
x.drop(["Cumulative_LIN_flow","Cumulative_product_flow"], 1,inplace=True)
df_shuffled = shuffle(x, random_state=123)
X = df_shuffled[df_shuffled.columns[:-1]]
X = scale(df_shuffled.drop(["LIN_flow", "_time"], 1))
y = df_shuffled["LIN_flow"]

df_shuffled = df_shuffled.drop(["LIN_flow"], 1)
print(X)
print('\n')
print(y)
# Out:
# [[-0.32669667  0.10418612  0.14644281 ... -0.64130615 -0.64248394
#   -0.57679886]
#  [ 0.38759734  0.26332297  0.2737845  ... -0.03794933 -0.06992851
#    0.06109701]
#  [ 0.34681188  0.16913991  0.19804532 ...  0.27684554  0.17545239
#    1.12277372]
#  ...
#  [-0.78635798  0.32584107  0.26379681 ... -0.65005045 -0.64248394
#    0.62436097]
#  [ 0.3545279   0.08875969  0.15892732 ... -0.1822303  -0.06992851
#   -1.72118407]
#  [ 0.33358425  0.11717685  0.17640548 ...  0.22875188  0.17545239
#   -0.03265693]]
#
#
# 499      331.47772
# 31       851.14710
# 1158     920.11560
# 163     1146.21610
# 491      397.10345
#            ...
# 1238     319.60196
# 1147      95.59321
# 106     1134.02540
# 1041    1033.78920
# 1122     870.18524
# Name: LIN_flow, Length: 1296, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
regr = LinearRegression()
regr.fit(X, y)
print('Коэффициенты: ')
list(zip(df_shuffled.columns, regr.coef_))
# Out:
# Коэффициенты:
# [('BeltAmpere_belt1', 89.25213151143912),
#  ('BeltAmpere_belt2', -129.98473742420816),
#  ('BeltAmpere_belt3', 85.08519333789731),
#  ('FanAmpere_exhaust1', 11.2751989717066),
#  ('FanAmpere_exhaust2', -39.53525969277408),
#  ('FanAmpere_side', -8957.15413668544),
#  ('FanAmpere_top', 7726.9358902507665),
#  ('Fanspeed_exhaust1', 105.69323519468118),
#  ('Fanspeed_exhaust2', -72.49225771381353),
#  ('Fanspeed_side', 1599.9796887378136),
#  ('Fanspeed_top', -5.133969176000364),
#  ('Product_flow', 84.66224353632352),
#  ('ResidenceTime_belt1', -212.9020232003989),
#  ('ResidenceTime_belt2', -4.8967973037224),
#  ('ResidenceTime_belt3', -4.89679730369033),
#  ('Temp_exhaust_in', -65.6635616773037),
#  ('Temp_exhaust_out', -12.997031545503146),
#  ('Temp_product_in', 236.1263054430093),
#  ('Temp_product_out', -33.270428342149955),
#  ('Temp_tunnel_measured', -104.08858685809126),
#  ('Temp_tunnel_set', 264.78421382269494),
#  ('Vanne_opening_rate', -30.789122230516973)]

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
regLasso = Lasso()
regLasso.fit(X, y)
print('Коэффициенты:')
list(zip(df_shuffled.columns, regLasso.coef_))
# Out:
# Коэффициенты:
# [('BeltAmpere_belt1', 3.1303582743320533),
#  ('BeltAmpere_belt2', -0.0),
#  ('BeltAmpere_belt3', 0.0),
#  ('FanAmpere_exhaust1', 0.0),
#  ('FanAmpere_exhaust2', -6.638129767999081),
#  ('FanAmpere_side', 0.0),
#  ('FanAmpere_top', 73.7103866330674),
#  ('Fanspeed_exhaust1', 34.93468959650671),
#  ('Fanspeed_exhaust2', 0.0),
#  ('Fanspeed_side', 0.0),
#  ('Fanspeed_top', -0.0),
#  ('Product_flow', 51.43701673449592),
#  ('ResidenceTime_belt1', -71.85398818267964),
#  ('ResidenceTime_belt2', 0.0),
#  ('ResidenceTime_belt3', 0.0),
#  ('Temp_exhaust_in', -83.20337412683787),
#  ('Temp_exhaust_out', -46.42080583317327),
#  ('Temp_product_in', 208.36605383775168),
#  ('Temp_product_out', -19.09834947236911),
#  ('Temp_tunnel_measured', -15.973066060216999),
#  ('Temp_tunnel_set', 0.0),
#  ('Vanne_opening_rate', 16.807132822467306)]

# %%
regRidge = Ridge()
regRidge.fit(X, y)
print('Коэффициенты: ')
list(zip(df_shuffled.columns, regRidge.coef_))
# Out:
# Коэффициенты:
# [('BeltAmpere_belt1', 31.363543590227653),
#  ('BeltAmpere_belt2', -176.54924289059556),
#  ('BeltAmpere_belt3', 47.89369468912203),
#  ('FanAmpere_exhaust1', -2.6331994624733075),
#  ('FanAmpere_exhaust2', -37.034027237951506),
#  ('FanAmpere_side', -318.2520003645286),
#  ('FanAmpere_top', 696.3067967478084),
#  ('Fanspeed_exhaust1', 127.9034437876767),
#  ('Fanspeed_exhaust2', -73.47517899967941),
#  ('Fanspeed_side', 52.09893170442196),
#  ('Fanspeed_top', -167.3628588445719),
#  ('Product_flow', 55.34100324700499),
#  ('ResidenceTime_belt1', -141.2765028067344),
#  ('ResidenceTime_belt2', 31.27587719137936),
#  ('ResidenceTime_belt3', 31.275877191377425),
#  ('Temp_exhaust_in', -84.63697304529818),
#  ('Temp_exhaust_out', -41.23282029842006),
#  ('Temp_product_in', 207.65111732205702),
#  ('Temp_product_out', -23.079036604160684),
#  ('Temp_tunnel_measured', -134.01660318592957),
#  ('Temp_tunnel_set', 198.2605619891143),
#  ('Vanne_opening_rate', 22.0458601919656)]

# %%
# Код 3.1 (1 балл)
alphas = np.arange(1, 500, 50)
coefs_lasso = np.zeros((alphas.shape[0], X.shape[1])) # матрица весов размера (число регрессоров) x (число признаков)
coefs_ridge = np.zeros((alphas.shape[0], X.shape[1]))
# Для каждого значения коэффициента из alphas обучите регрессор Lasso
# и запишите веса в соответствующую строку матрицы coefs_lasso (вспомните встроенную в python функцию enumerate),
# а затем обучите Ridge и запишите веса в coefs_ridge.

for i, item in enumerate(alphas):
    reg_Lasso = Lasso(alpha = alphas[i])
    reg_Lasso.fit(X, y)
    coefs_lasso[i,:] = reg_Lasso.coef_

for i, item in enumerate(alphas):
    reg_Ridge = Ridge(alpha = alphas[i])
    reg_Ridge.fit(X, y)
    coefs_ridge[i,:] = reg_Ridge.coef_

# %%
plt.figure(figsize=(8, 5))

for coef, feature in zip(coefs_lasso.T, df_shuffled.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))
    
plt.legend(loc="upper right", bbox_to_anchor=(1.6, 1))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Lasso")

plt.figure(figsize=(8, 5))

for coef, feature in zip(coefs_ridge.T, df_shuffled.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))
    
plt.legend(loc="upper right", bbox_to_anchor=(1.6, 1))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Ridge")
# Out:
# Text(0.5, 1.0, 'Ridge')

# %%
from sklearn.linear_model import LassoCV

# %%
# Код 3.2 (1 балл)
# Обучите регрессор LassoCV на всех параметрах регуляризации из alpha
# Постройте график _усредненного_ по строкам MSE в зависимости от alpha. 
# Выведите выбранное alpha, а также пары "признак-коэффициент" для обученного вектора коэффициентов

alphas = np.arange(1, 100, 5)
regLassoCV = LassoCV(alphas=alphas)
regLassoCV.fit(X, y)
print('Матрица переменной mse_path_: \n', regLassoCV.mse_path_)

plt.plot(regLassoCV.alphas_, regLassoCV.mse_path_.mean(axis=1))
plt.xlabel('alphas')
plt.ylabel('MSE')
plt.show()

print('Выбранное alpha:', regLassoCV.alpha_, '\n')
print('Вектор коэффициентов для выбранного alpha:')
list(zip(df_shuffled.columns, regLassoCV.coef_))
# Out:
# Матрица переменной mse_path_:
#  [[57194.04456191 48194.30838341 64270.21601825 55387.10533647
#   48251.0176358 ]
#  [55360.50552344 46660.80555887 62763.47041141 54079.04315256
#   46712.86577719]
#  [53623.53100941 45142.43208759 61338.63216874 52470.30990165
#   45264.45177095]
#  [51565.89787369 43706.71175683 59996.1742569  50770.76980036
#   43385.68228646]
#  [49442.16553301 42204.32771747 58736.09639229 49178.47080334
#   41571.11940598]
#  [47412.08961329 40703.90756063 56806.45082305 47693.29750563
#   39883.6500012 ]
#  [45490.08862207 39280.04492326 54876.59378675 46315.24793234
#   38324.86482135]
#  [43716.16298831 37956.11931941 53058.12155016 45044.32208414
#   36893.80871851]
#  [42089.60530689 36732.02960866 51235.95710282 43843.88326379
#   35590.48830332]
#  [40610.42265863 35660.17687978 49540.5684116  42571.62722748
#   34414.88584966]
#  [39278.64447399 34731.66816326 47970.60126852 41427.67330414
#   33367.00137523]
#  [38091.59702863 33915.94355635 46526.06358881 40410.5254677
#   32446.83489058]
#  [37053.44920111 33212.71012808 45206.94316798 39520.18821638
#   31630.96511213]
#  [36168.32377822 32622.06201624 44013.23996283 38756.72322677
#   30919.71489869]
#  [35435.73221963 32143.57552848 42944.95409676 38120.05959999
#   30345.16788212]
#  [34855.84808438 31777.52158174 41967.28602311 37513.84045295
#   29906.49914531]
#  [34182.79159332 31543.97849055 40729.07943146 36682.14742807
#   29323.73532046]
#  [33299.62209973 30383.26312906 39218.07211503 35842.01555949
#   28735.08434866]
#  [32693.88973676 28965.50953308 37850.00820249 35754.03375886
#   28470.52380117]
#  [32195.79982618 27420.33013454 36435.21468813 37250.08271764
#   27497.15507878]]
# Выбранное alpha: 1
#
# Вектор коэффициентов для выбранного alpha:
# [('BeltAmpere_belt1', 3.1303582743320533),
#  ('BeltAmpere_belt2', -0.0),
#  ('BeltAmpere_belt3', 0.0),
#  ('FanAmpere_exhaust1', 0.0),
#  ('FanAmpere_exhaust2', -6.638129767999081),
#  ('FanAmpere_side', 0.0),
#  ('FanAmpere_top', 73.7103866330674),
#  ('Fanspeed_exhaust1', 34.93468959650671),
#  ('Fanspeed_exhaust2', 0.0),
#  ('Fanspeed_side', 0.0),
#  ('Fanspeed_top', -0.0),
#  ('Product_flow', 51.43701673449592),
#  ('ResidenceTime_belt1', -71.85398818267964),
#  ('ResidenceTime_belt2', 0.0),
#  ('ResidenceTime_belt3', 0.0),
#  ('Temp_exhaust_in', -83.20337412683787),
#  ('Temp_exhaust_out', -46.42080583317327),
#  ('Temp_product_in', 208.36605383775168),
#  ('Temp_product_out', -19.09834947236911),
#  ('Temp_tunnel_measured', -15.973066060216999),
#  ('Temp_tunnel_set', 0.0),
#  ('Vanne_opening_rate', 16.807132822467306)]

# %%
min_alphas = []
for i in range(3):
    z = dict(zip(regLassoCV.alphas_, regLassoCV.mse_path_[:, i]))
    min_alphas.append(sorted(z, key=z.get)[0])
    plt.figure(figsize=(8, 5))
    plt.plot(regLassoCV.alphas_, regLassoCV.mse_path_[:, i], label='mse{} from alpha'.format(i))
    plt.legend(loc='best')
    plt.xlabel('alpha')
    plt.ylabel('mse')

min_alphas
# Out:
# [1, 1, 1]
