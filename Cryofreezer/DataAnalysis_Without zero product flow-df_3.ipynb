# %%
# ondoing main libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# import jupyterthemes as jt
# from jupyterthemes import jtplot
# !jt -t onedork -ofs 10 -dfs 9 -nfs 11 -tfs 11
# jtplot.style(theme = 'onedork', fscale = 1.4 , context = 'notebook', ticks = True, 
#              grid = False)

# %%
# !jt -r
# Out:
# Reset css and font defaults in:
# /home/tater/.jupyter/custom &
# /home/tater/.local/share/jupyter/nbextensions

# %%
# hiding possible warning in the system
import warnings
warnings.filterwarnings('ignore')

# %%
df_1 = pd.read_csv("Cryofreezer_all_variables_29.csv", delimiter=',')
df_2 = pd.read_csv("Cryofreezer_all_variables_30.csv", delimiter=',')
df_3 = pd.read_csv("Cryofreezer_all_variables_31.csv", delimiter=',')
df_4 = pd.read_csv("Cryofreezer_all_variables_32.csv", delimiter=',')
df_5 = pd.read_csv("Cryofreezer_all_variables_33.csv", delimiter=',')

# %%
# entering a deltatime between to moments of experiments
def deltatime(dataframe):
    begin = dataframe[0]
    for i in range(len(dataframe)):   
        cur = dataframe[i]
        delta = cur - begin
        dataframe[i] = delta.seconds

# %%
#file concatanation
df_all = df_3
df_all
# Out:
#       BeltAmpere_belt1  BeltAmpere_belt1_qc  BeltAmpere_belt2  \
# 0             0.000000          -2138963968          0.000000
# 1             0.002441                    0          0.001831
# 2             0.002441                    0          0.001831
# 3             0.000000          -2138963968          0.000000
# 4             0.002441                    0          0.002441
# ...                ...                  ...               ...
# 7995          0.002441                    0          0.002441
# 7996          0.000000          -2138963968          0.000000
# 7997          0.002441                    0          0.002441
# 7998          0.002441                    0          0.002441
# 7999          0.000000          -2138963968          0.000000
#
#       BeltAmpere_belt2_qc  BeltAmpere_belt3  BeltAmpere_belt3_qc  \
# 0             -2138963968          0.000000          -2138963968
# 1                       0          0.002441                    0
# 2                       0          0.002441                    0
# 3             -2138963968          0.000000          -2138963968
# 4                       0          0.002441                    0
# ...                   ...               ...                  ...
# 7995                    0          0.002441                    0
# 7996          -2138963968          0.000000          -2138963968
# 7997                    0          0.002441                    0
# 7998                    0          0.003052                    0
# 7999          -2138963968          0.000000          -2138963968
#
#       Cumulative_LIN_flow  Cumulative_LIN_flow_qc  Cumulative_product_flow  \
# 0                       0             -2138963968                        0
# 1                  388372                       0                   210730
# 2                  388376                       0                   210730
# 3                       0             -2138963968                        0
# 4                  388382                       0                   210730
# ...                   ...                     ...                      ...
# 7995                 9686                       0                     7094
# 7996                    0             -2138963968                        0
# 7997                 9693                       0                     7094
# 7998                 9696                       0                     7094
# 7999                    0             -2138963968                        0
#
#       Cumulative_product_flow_qc  ...  Temp_product_in_qc  Temp_product_out  \
# 0                    -2138963968  ...         -2138963968          0.000000
# 1                              0  ...                   0          0.000000
# 2                              0  ...                   0          0.000000
# 3                    -2138963968  ...         -2138963968          0.000000
# 4                              0  ...                   0          0.000000
# ...                          ...  ...                 ...               ...
# 7995                           0  ...                   0          3.743961
# 7996                 -2138963968  ...         -2138963968          0.000000
# 7997                           0  ...                   0          3.740703
# 7998                           0  ...                   0          3.833601
# 7999                 -2138963968  ...         -2138963968          0.000000
#
#       Temp_product_out_qc  Temp_tunnel_measured  Temp_tunnel_measured_qc  \
# 0             -2138963968                   0.0              -2138963968
# 1                       0                  10.8                        0
# 2                       0                  10.9                        0
# 3             -2138963968                   0.0              -2138963968
# 4                       0                  11.3                        0
# ...                   ...                   ...                      ...
# 7995                    0                  20.9                        0
# 7996          -2138963968                   0.0              -2138963968
# 7997                    0                  20.9                        0
# 7998                    0                  20.5                        0
# 7999          -2138963968                   0.0              -2138963968
#
#       Temp_tunnel_set  Temp_tunnel_set_qc  Vanne_opening_rate  \
# 0                   0         -2138963968                 0.0
# 1                   0                   0                 0.0
# 2                   0                   0                 0.0
# 3                   0         -2138963968                 0.0
# 4                   0                   0                 0.0
# ...               ...                 ...                 ...
# 7995                0                   0                 0.0
# 7996                0         -2138963968                 0.0
# 7997                0                   0                 0.0
# 7998                0                   0                 0.0
# 7999                0         -2138963968                 0.0
#
#       Vanne_opening_rate_qc                     _time
# 0               -2138963968  2020-09-16T00:07:32.645Z
# 1                         0  2020-09-16T00:08:32.682Z
# 2                         0  2020-09-16T00:09:32.686Z
# 3               -2138963968  2020-09-16T00:10:32.658Z
# 4                         0  2020-09-16T00:11:32.683Z
# ...                     ...                       ...
# 7995                      0  2020-09-21T14:00:59.214Z
# 7996            -2138963968  2020-09-21T14:01:59.154Z
# 7997                      0  2020-09-21T14:02:59.218Z
# 7998                      0  2020-09-21T14:03:59.220Z
# 7999            -2138963968  2020-09-21T14:04:59.142Z
#
# [8000 rows x 51 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 51 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   BeltAmpere_belt1            8000 non-null   float64
#  1   BeltAmpere_belt1_qc         8000 non-null   int64
#  2   BeltAmpere_belt2            8000 non-null   float64
#  3   BeltAmpere_belt2_qc         8000 non-null   int64
#  4   BeltAmpere_belt3            8000 non-null   float64
#  5   BeltAmpere_belt3_qc         8000 non-null   int64
#  6   Cumulative_LIN_flow         8000 non-null   int64
#  7   Cumulative_LIN_flow_qc      8000 non-null   int64
#  8   Cumulative_product_flow     8000 non-null   int64
#  9   Cumulative_product_flow_qc  8000 non-null   int64
#  10  FanAmpere_exhaust1          8000 non-null   float64
#  11  FanAmpere_exhaust1_qc       8000 non-null   int64
#  12  FanAmpere_exhaust2          8000 non-null   float64
#  13  FanAmpere_exhaust2_qc       8000 non-null   int64
#  14  FanAmpere_side              8000 non-null   float64
#  15  FanAmpere_side_qc           8000 non-null   int64
#  16  FanAmpere_top               8000 non-null   float64
#  17  FanAmpere_top_qc            8000 non-null   int64
#  18  Fanspeed_exhaust1           8000 non-null   int64
#  19  Fanspeed_exhaust1_qc        8000 non-null   int64
#  20  Fanspeed_exhaust2           8000 non-null   int64
#  21  Fanspeed_exhaust2_qc        8000 non-null   int64
#  22  Fanspeed_side               8000 non-null   int64
#  23  Fanspeed_side_qc            8000 non-null   int64
#  24  Fanspeed_top                8000 non-null   int64
#  25  Fanspeed_top_qc             8000 non-null   int64
#  26  LIN_flow                    8000 non-null   float64
#  27  LIN_flow_qc                 8000 non-null   int64
#  28  Product_flow                8000 non-null   float64
#  29  Product_flow_qc             8000 non-null   int64
#  30  ResidenceTime_belt1         8000 non-null   int64
#  31  ResidenceTime_belt1_qc      8000 non-null   int64
#  32  ResidenceTime_belt2         8000 non-null   int64
#  33  ResidenceTime_belt2_qc      8000 non-null   int64
#  34  ResidenceTime_belt3         8000 non-null   int64
#  35  ResidenceTime_belt3_qc      8000 non-null   int64
#  36  Temp_exhaust_in             8000 non-null   float64
#  37  Temp_exhaust_in_qc          8000 non-null   int64
#  38  Temp_exhaust_out            8000 non-null   float64
#  39  Temp_exhaust_out_qc         8000 non-null   int64
#  40  Temp_product_in             8000 non-null   float64
#  41  Temp_product_in_qc          8000 non-null   int64
#  42  Temp_product_out            8000 non-null   float64
#  43  Temp_product_out_qc         8000 non-null   int64
#  44  Temp_tunnel_measured        8000 non-null   float64
#  45  Temp_tunnel_measured_qc     8000 non-null   int64
#  46  Temp_tunnel_set             8000 non-null   int64
#  47  Temp_tunnel_set_qc          8000 non-null   int64
#  48  Vanne_opening_rate          8000 non-null   float64
#  49  Vanne_opening_rate_qc       8000 non-null   int64
#  50  _time                       8000 non-null   object
# dtypes: float64(15), int64(35), object(1)
# memory usage: 3.1+ MB

# %%
df_all_short = df_all.iloc[:, ::2]
df_all_short
# Out:
#       BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# 0             0.000000          0.000000          0.000000
# 1             0.002441          0.001831          0.002441
# 2             0.002441          0.001831          0.002441
# 3             0.000000          0.000000          0.000000
# 4             0.002441          0.002441          0.002441
# ...                ...               ...               ...
# 7995          0.002441          0.002441          0.002441
# 7996          0.000000          0.000000          0.000000
# 7997          0.002441          0.002441          0.002441
# 7998          0.002441          0.002441          0.003052
# 7999          0.000000          0.000000          0.000000
#
#       Cumulative_LIN_flow  Cumulative_product_flow  FanAmpere_exhaust1  \
# 0                       0                        0            0.000000
# 1                  388372                   210730            3.014224
# 2                  388376                   210730            2.981058
# 3                       0                        0            0.000000
# 4                  388382                   210730            3.012915
# ...                   ...                      ...                 ...
# 7995                 9686                     7094            0.002618
# 7996                    0                        0            0.000000
# 7997                 9693                     7094            0.002182
# 7998                 9696                     7094            3.055246
# 7999                    0                        0            0.000000
#
#       FanAmpere_exhaust2  FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# 0               0.000000        0.000000       0.000000                  0
# 1               3.566708        0.000000       0.000000                100
# 2               3.507794        0.000000       0.000000                100
# 3               0.000000        0.000000       0.000000                  0
# 4               3.520014        0.000000       0.000000                100
# ...                  ...             ...            ...                ...
# 7995            0.002618        0.017853       0.017853                  0
# 7996            0.000000        0.000000       0.000000                  0
# 7997            0.002618        0.016479       0.016479                  0
# 7998            3.371201        0.000000       0.000000                100
# 7999            0.000000        0.000000       0.000000                  0
#
#       ...  ResidenceTime_belt2  ResidenceTime_belt3  Temp_exhaust_in  \
# 0     ...                    0                    0              0.0
# 1     ...                    0                    0             12.7
# 2     ...                    0                    0             12.9
# 3     ...                    0                    0              0.0
# 4     ...                    0                    0             13.3
# ...   ...                  ...                  ...              ...
# 7995  ...                    0                    0             26.8
# 7996  ...                    0                    0              0.0
# 7997  ...                    0                    0             27.1
# 7998  ...                    0                    0             20.8
# 7999  ...                    0                    0              0.0
#
#       Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# 0                  0.0              0.0          0.000000
# 1                 12.2              0.0          0.000000
# 2                 12.6              0.0          0.000000
# 3                  0.0              0.0          0.000000
# 4                 13.1              0.0          0.000000
# ...                ...              ...               ...
# 7995              27.7              0.0          3.743961
# 7996               0.0              0.0          0.000000
# 7997              27.9              0.0          3.740703
# 7998              21.5              0.0          3.833601
# 7999               0.0              0.0          0.000000
#
#       Temp_tunnel_measured  Temp_tunnel_set  Vanne_opening_rate  \
# 0                      0.0                0                 0.0
# 1                     10.8                0                 0.0
# 2                     10.9                0                 0.0
# 3                      0.0                0                 0.0
# 4                     11.3                0                 0.0
# ...                    ...              ...                 ...
# 7995                  20.9                0                 0.0
# 7996                   0.0                0                 0.0
# 7997                  20.9                0                 0.0
# 7998                  20.5                0                 0.0
# 7999                   0.0                0                 0.0
#
#                          _time
# 0     2020-09-16T00:07:32.645Z
# 1     2020-09-16T00:08:32.682Z
# 2     2020-09-16T00:09:32.686Z
# 3     2020-09-16T00:10:32.658Z
# 4     2020-09-16T00:11:32.683Z
# ...                        ...
# 7995  2020-09-21T14:00:59.214Z
# 7996  2020-09-21T14:01:59.154Z
# 7997  2020-09-21T14:02:59.218Z
# 7998  2020-09-21T14:03:59.220Z
# 7999  2020-09-21T14:04:59.142Z
#
# [8000 rows x 26 columns]

# %%
df_all_short["_time"] = pd.to_datetime(df_all_short["_time"])

# %%
df_all_short
# Out:
#       BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# 0             0.000000          0.000000          0.000000
# 1             0.002441          0.001831          0.002441
# 2             0.002441          0.001831          0.002441
# 3             0.000000          0.000000          0.000000
# 4             0.002441          0.002441          0.002441
# ...                ...               ...               ...
# 7995          0.002441          0.002441          0.002441
# 7996          0.000000          0.000000          0.000000
# 7997          0.002441          0.002441          0.002441
# 7998          0.002441          0.002441          0.003052
# 7999          0.000000          0.000000          0.000000
#
#       Cumulative_LIN_flow  Cumulative_product_flow  FanAmpere_exhaust1  \
# 0                       0                        0            0.000000
# 1                  388372                   210730            3.014224
# 2                  388376                   210730            2.981058
# 3                       0                        0            0.000000
# 4                  388382                   210730            3.012915
# ...                   ...                      ...                 ...
# 7995                 9686                     7094            0.002618
# 7996                    0                        0            0.000000
# 7997                 9693                     7094            0.002182
# 7998                 9696                     7094            3.055246
# 7999                    0                        0            0.000000
#
#       FanAmpere_exhaust2  FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# 0               0.000000        0.000000       0.000000                  0
# 1               3.566708        0.000000       0.000000                100
# 2               3.507794        0.000000       0.000000                100
# 3               0.000000        0.000000       0.000000                  0
# 4               3.520014        0.000000       0.000000                100
# ...                  ...             ...            ...                ...
# 7995            0.002618        0.017853       0.017853                  0
# 7996            0.000000        0.000000       0.000000                  0
# 7997            0.002618        0.016479       0.016479                  0
# 7998            3.371201        0.000000       0.000000                100
# 7999            0.000000        0.000000       0.000000                  0
#
#       ...  ResidenceTime_belt2  ResidenceTime_belt3  Temp_exhaust_in  \
# 0     ...                    0                    0              0.0
# 1     ...                    0                    0             12.7
# 2     ...                    0                    0             12.9
# 3     ...                    0                    0              0.0
# 4     ...                    0                    0             13.3
# ...   ...                  ...                  ...              ...
# 7995  ...                    0                    0             26.8
# 7996  ...                    0                    0              0.0
# 7997  ...                    0                    0             27.1
# 7998  ...                    0                    0             20.8
# 7999  ...                    0                    0              0.0
#
#       Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# 0                  0.0              0.0          0.000000
# 1                 12.2              0.0          0.000000
# 2                 12.6              0.0          0.000000
# 3                  0.0              0.0          0.000000
# 4                 13.1              0.0          0.000000
# ...                ...              ...               ...
# 7995              27.7              0.0          3.743961
# 7996               0.0              0.0          0.000000
# 7997              27.9              0.0          3.740703
# 7998              21.5              0.0          3.833601
# 7999               0.0              0.0          0.000000
#
#       Temp_tunnel_measured  Temp_tunnel_set  Vanne_opening_rate  \
# 0                      0.0                0                 0.0
# 1                     10.8                0                 0.0
# 2                     10.9                0                 0.0
# 3                      0.0                0                 0.0
# 4                     11.3                0                 0.0
# ...                    ...              ...                 ...
# 7995                  20.9                0                 0.0
# 7996                   0.0                0                 0.0
# 7997                  20.9                0                 0.0
# 7998                  20.5                0                 0.0
# 7999                   0.0                0                 0.0
#
#                                 _time
# 0    2020-09-16 00:07:32.645000+00:00
# 1    2020-09-16 00:08:32.682000+00:00
# 2    2020-09-16 00:09:32.686000+00:00
# 3    2020-09-16 00:10:32.658000+00:00
# 4    2020-09-16 00:11:32.683000+00:00
# ...                               ...
# 7995 2020-09-21 14:00:59.214000+00:00
# 7996 2020-09-21 14:01:59.154000+00:00
# 7997 2020-09-21 14:02:59.218000+00:00
# 7998 2020-09-21 14:03:59.220000+00:00
# 7999 2020-09-21 14:04:59.142000+00:00
#
# [8000 rows x 26 columns]

# %%
df_all_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   BeltAmpere_belt1         8000 non-null   float64
#  1   BeltAmpere_belt2         8000 non-null   float64
#  2   BeltAmpere_belt3         8000 non-null   float64
#  3   Cumulative_LIN_flow      8000 non-null   int64
#  4   Cumulative_product_flow  8000 non-null   int64
#  5   FanAmpere_exhaust1       8000 non-null   float64
#  6   FanAmpere_exhaust2       8000 non-null   float64
#  7   FanAmpere_side           8000 non-null   float64
#  8   FanAmpere_top            8000 non-null   float64
#  9   Fanspeed_exhaust1        8000 non-null   int64
#  10  Fanspeed_exhaust2        8000 non-null   int64
#  11  Fanspeed_side            8000 non-null   int64
#  12  Fanspeed_top             8000 non-null   int64
#  13  LIN_flow                 8000 non-null   float64
#  14  Product_flow             8000 non-null   float64
#  15  ResidenceTime_belt1      8000 non-null   int64
#  16  ResidenceTime_belt2      8000 non-null   int64
#  17  ResidenceTime_belt3      8000 non-null   int64
#  18  Temp_exhaust_in          8000 non-null   float64
#  19  Temp_exhaust_out         8000 non-null   float64
#  20  Temp_product_in          8000 non-null   float64
#  21  Temp_product_out         8000 non-null   float64
#  22  Temp_tunnel_measured     8000 non-null   float64
#  23  Temp_tunnel_set          8000 non-null   int64
#  24  Vanne_opening_rate       8000 non-null   float64
#  25  _time                    8000 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(15), int64(10)
# memory usage: 1.6 MB

# %%
x_time = df_all_short["_time"]
y_LIN = df_all_short["LIN_flow"]
y_PROD = df_all_short["Product_flow"]

# %%
plt.figure(figsize=(35, 35))
ax = plt.subplot(3,3,3)
plt.plot(x_time, y_LIN, color="red", label="LIN_flow")
plt.plot(x_time, y_PROD, color="black", label="Product_flow", alpha=0.5)
plt.xlabel("Time")
plt.ylabel("LIN_flow")
plt.grid(True)
plt.legend()

# %%
df_w_o_prod_flow = df_all_short[df_all_short["Product_flow"] >= 1.175381e-33]

# %%
df_w_o_prod_flow = df_w_o_prod_flow[df_all_short["Product_flow"] != 0]

# %%
df_w_o_prod_flow.shape
# Out:
# (445, 26)

# %%
df_w_o_prod_flow.reset_index(inplace=True, drop=True)

# %%
df_w_o_prod_flow
# Out:
#      BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# 0            0.000000          0.000000          0.000000
# 1            0.000000          0.000000          0.000000
# 2            2.430420          3.606567          3.562622
# 3            2.427368          3.591919          3.565674
# 4            2.427979          3.588257          3.535767
# ..                ...               ...               ...
# 440          0.000000          0.000000          0.000000
# 441          0.000000          0.000000          0.000000
# 442          0.000000          0.000000          0.000000
# 443          0.000000          0.000000          0.000000
# 444          0.000000          0.000000          0.000000
#
#      Cumulative_LIN_flow  Cumulative_product_flow  FanAmpere_exhaust1  \
# 0                  22202                    28018            0.000000
# 1                  22213                    28018            0.000000
# 2                  22230                    28023            2.151895
# 3                  22241                    28037            2.158005
# 4                  22258                    28063            2.165860
# ..                   ...                      ...                 ...
# 440                 7161                     7094            3.006805
# 441                 7169                     7094            2.984549
# 442                 7177                     7094            2.994586
# 443                 7186                     7094            3.000259
# 444                 7194                     7094            3.002441
#
#      FanAmpere_exhaust2  FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# 0              0.000000        0.000000       0.000000                  0
# 1              0.000000        0.000000       0.000000                  0
# 2              2.454321        8.013153       8.216400                 50
# 3              2.451267        8.022766       8.128509                 50
# 4              2.457376        8.015900       8.198547                 50
# ..                  ...             ...            ...                ...
# 440            3.526560        0.000000       0.000000                100
# 441            3.571509        0.000000       0.000000                100
# 442            3.533978        0.000000       0.000000                100
# 443            3.520450        0.000000       0.000000                100
# 444            3.274319        0.000000       0.000000                100
#
#      ...  ResidenceTime_belt2  ResidenceTime_belt3  Temp_exhaust_in  \
# 0    ...                    0                    0             -8.9
# 1    ...                    0                    0            -10.7
# 2    ...                  150                  150             -8.3
# 3    ...                  150                  150            -11.0
# 4    ...                  150                  150             -8.5
# ..   ...                  ...                  ...              ...
# 440  ...                    0                    0             10.5
# 441  ...                    0                    0             10.6
# 442  ...                    0                    0             10.7
# 443  ...                    0                    0             10.8
# 444  ...                    0                    0             10.9
#
#      Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# 0                 7.4        13.852458        -29.640795
# 1                 7.7        13.908852        -30.846660
# 2                 7.3        14.027567        -29.201593
# 3                 7.2        14.269064        -30.032703
# 4                 7.4        15.200426        -31.021559
# ..                ...              ...               ...
# 440              10.5         0.000000          0.000000
# 441              11.2         0.000000          0.000000
# 442              11.3         0.000000          0.000000
# 443              11.5         0.000000          0.000000
# 444              10.8         0.000000          0.000000
#
#      Temp_tunnel_measured  Temp_tunnel_set  Vanne_opening_rate  \
# 0                     0.0                0            0.000000
# 1                     0.0                0            0.000000
# 2                   -79.0              -82           68.204190
# 3                   -85.0              -82            4.335089
# 4                   -79.0              -82           68.605110
# ..                    ...              ...                 ...
# 440                   8.6                0            0.000000
# 441                   8.8                0            0.000000
# 442                   8.9                0            0.000000
# 443                   9.0                0            0.000000
# 444                   9.1                0            0.000000
#
#                                _time
# 0   2020-09-18 07:44:40.772000+00:00
# 1   2020-09-18 07:45:42.232000+00:00
# 2   2020-09-18 07:46:40.775000+00:00
# 3   2020-09-18 07:47:40.773000+00:00
# 4   2020-09-18 07:48:42.174000+00:00
# ..                               ...
# 440 2020-09-18 17:45:44.844000+00:00
# 441 2020-09-18 17:46:43.431000+00:00
# 442 2020-09-18 17:47:43.432000+00:00
# 443 2020-09-18 17:48:44.822000+00:00
# 444 2020-09-18 17:49:43.436000+00:00
#
# [445 rows x 26 columns]

# %%
df_w_o_prod_flow[["LIN_flow", "Product_flow", "Cumulative_LIN_flow", "Cumulative_product_flow", "_time"]].head()
# Out:
#     LIN_flow  Product_flow  Cumulative_LIN_flow  Cumulative_product_flow  \
# 0  876.40470    1001.46310                22202                    28018
# 1  683.84106     484.43436                22213                    28018
# 2  942.69030     399.49393                22230                    28023
# 3  742.46710     652.15940                22241                    28037
# 4  963.67926    1100.50650                22258                    28063
#
#                              _time
# 0 2020-09-18 07:44:40.772000+00:00
# 1 2020-09-18 07:45:42.232000+00:00
# 2 2020-09-18 07:46:40.775000+00:00
# 3 2020-09-18 07:47:40.773000+00:00
# 4 2020-09-18 07:48:42.174000+00:00

# %%
df_w_o_prod_flow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445 entries, 0 to 444
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   BeltAmpere_belt1         445 non-null    float64
#  1   BeltAmpere_belt2         445 non-null    float64
#  2   BeltAmpere_belt3         445 non-null    float64
#  3   Cumulative_LIN_flow      445 non-null    int64
#  4   Cumulative_product_flow  445 non-null    int64
#  5   FanAmpere_exhaust1       445 non-null    float64
#  6   FanAmpere_exhaust2       445 non-null    float64
#  7   FanAmpere_side           445 non-null    float64
#  8   FanAmpere_top            445 non-null    float64
#  9   Fanspeed_exhaust1        445 non-null    int64
#  10  Fanspeed_exhaust2        445 non-null    int64
#  11  Fanspeed_side            445 non-null    int64
#  12  Fanspeed_top             445 non-null    int64
#  13  LIN_flow                 445 non-null    float64
#  14  Product_flow             445 non-null    float64
#  15  ResidenceTime_belt1      445 non-null    int64
#  16  ResidenceTime_belt2      445 non-null    int64
#  17  ResidenceTime_belt3      445 non-null    int64
#  18  Temp_exhaust_in          445 non-null    float64
#  19  Temp_exhaust_out         445 non-null    float64
#  20  Temp_product_in          445 non-null    float64
#  21  Temp_product_out         445 non-null    float64
#  22  Temp_tunnel_measured     445 non-null    float64
#  23  Temp_tunnel_set          445 non-null    int64
#  24  Vanne_opening_rate       445 non-null    float64
#  25  _time                    445 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(15), int64(10)
# memory usage: 90.5 KB

# %%
x_time = df_w_o_prod_flow["_time"]
y_LIN = df_w_o_prod_flow["LIN_flow"]
y_PROD = df_w_o_prod_flow["Product_flow"]

# %%
plt.figure(figsize=(35, 35))
ax = plt.subplot(3,3,3)
plt.plot(x_time, y_LIN, color="red", label="LIN_flow")
plt.plot(x_time, y_PROD, color="black", label="Product_flow", alpha=0.5)
plt.xlabel("Time")
plt.ylabel("LIN_flow")
plt.grid(True)
plt.legend()

# %%
df_w_o_prod_flow.describe()
named_cols = df_w_o_prod_flow.columns[:-1]
named_cols
# Out:
# Index(['BeltAmpere_belt1', 'BeltAmpere_belt2', 'BeltAmpere_belt3',
#        'Cumulative_LIN_flow', 'Cumulative_product_flow', 'FanAmpere_exhaust1',
#        'FanAmpere_exhaust2', 'FanAmpere_side', 'FanAmpere_top',
#        'Fanspeed_exhaust1', 'Fanspeed_exhaust2', 'Fanspeed_side',
#        'Fanspeed_top', 'LIN_flow', 'Product_flow', 'ResidenceTime_belt1',
#        'ResidenceTime_belt2', 'ResidenceTime_belt3', 'Temp_exhaust_in',
#        'Temp_exhaust_out', 'Temp_product_in', 'Temp_product_out',
#        'Temp_tunnel_measured', 'Temp_tunnel_set', 'Vanne_opening_rate'],
#       dtype='object')

# %%
#Данные чистые, пустых значений нет
df_w_o_prod_flow.isnull().values.any()
df_w_o_prod_flow["_time"] = pd.to_datetime(df_w_o_prod_flow["_time"])

# %%
y = df_w_o_prod_flow["LIN_flow"]
x = df_w_o_prod_flow

# %%
print('Матрица корреляций всех признаков, кроме последнего:\n', x.iloc[:, :-1].corr())
print('\n')

print(x.shape)
# Out:
# Матрица корреляций всех признаков, кроме последнего:
#                           BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# BeltAmpere_belt1                 1.000000          0.997662          0.997189
# BeltAmpere_belt2                 0.997662          1.000000          0.999785
# BeltAmpere_belt3                 0.997189          0.999785          1.000000
# Cumulative_LIN_flow              0.000401          0.008596          0.007224
# Cumulative_product_flow          0.041006          0.049814          0.048649
# FanAmpere_exhaust1               0.781045          0.780359          0.780315
# FanAmpere_exhaust2               0.757863          0.756500          0.756705
# FanAmpere_side                   0.975562          0.985276          0.985797
# FanAmpere_top                    0.975524          0.985264          0.985822
# Fanspeed_exhaust1                0.565859          0.559215          0.559335
# Fanspeed_exhaust2                0.760196          0.757540          0.757536
# Fanspeed_side                    0.975537          0.985254          0.985784
# Fanspeed_top                     0.975537          0.985254          0.985784
# LIN_flow                         0.722344          0.728934          0.732209
# Product_flow                     0.852277          0.857553          0.857437
# ResidenceTime_belt1              0.997890          0.999838          0.999699
# ResidenceTime_belt2              0.997890          0.999838          0.999699
# ResidenceTime_belt3              0.997890          0.999838          0.999699
# Temp_exhaust_in                 -0.165877         -0.179757         -0.180713
# Temp_exhaust_out                -0.799874         -0.797299         -0.798935
# Temp_product_in                  0.958910          0.961290          0.962122
# Temp_product_out                -0.898913         -0.902665         -0.902923
# Temp_tunnel_measured            -0.957182         -0.960430         -0.960746
# Temp_tunnel_set                 -0.964891         -0.975595         -0.976474
# Vanne_opening_rate               0.526536          0.533900          0.533048
#
#                          Cumulative_LIN_flow  Cumulative_product_flow  \
# BeltAmpere_belt1                    0.000401                 0.041006
# BeltAmpere_belt2                    0.008596                 0.049814
# BeltAmpere_belt3                    0.007224                 0.048649
# Cumulative_LIN_flow                 1.000000                 0.998205
# Cumulative_product_flow             0.998205                 1.000000
# FanAmpere_exhaust1                 -0.015838                 0.013597
# FanAmpere_exhaust2                 -0.014447                 0.013915
# FanAmpere_side                      0.007556                 0.047621
# FanAmpere_top                       0.010758                 0.050885
# Fanspeed_exhaust1                  -0.062220                -0.044007
# Fanspeed_exhaust2                  -0.034772                -0.007017
# Fanspeed_side                       0.007558                 0.047647
# Fanspeed_top                        0.007558                 0.047647
# LIN_flow                            0.133361                 0.173248
# Product_flow                        0.039466                 0.083612
# ResidenceTime_belt1                 0.001252                 0.042081
# ResidenceTime_belt2                 0.001252                 0.042081
# ResidenceTime_belt3                 0.001252                 0.042081
# Temp_exhaust_in                    -0.711118                -0.739314
# Temp_exhaust_out                    0.298358                 0.263194
# Temp_product_in                    -0.099483                -0.055860
# Temp_product_out                   -0.209191                -0.249632
# Temp_tunnel_measured               -0.106195                -0.149214
# Temp_tunnel_set                    -0.120031                -0.161396
# Vanne_opening_rate                  0.242928                 0.269498
#
#                          FanAmpere_exhaust1  FanAmpere_exhaust2  \
# BeltAmpere_belt1                   0.781045            0.757863
# BeltAmpere_belt2                   0.780359            0.756500
# BeltAmpere_belt3                   0.780315            0.756705
# Cumulative_LIN_flow               -0.015838           -0.014447
# Cumulative_product_flow            0.013597            0.013915
# FanAmpere_exhaust1                 1.000000            0.996851
# FanAmpere_exhaust2                 0.996851            1.000000
# FanAmpere_side                     0.760235            0.736020
# FanAmpere_top                      0.760651            0.736699
# Fanspeed_exhaust1                  0.920998            0.942922
# Fanspeed_exhaust2                  0.994327            0.998009
# Fanspeed_side                      0.760189            0.735991
# Fanspeed_top                       0.760189            0.735991
# LIN_flow                           0.582009            0.578603
# Product_flow                       0.657608            0.635719
# ResidenceTime_belt1                0.780986            0.757221
# ResidenceTime_belt2                0.780986            0.757221
# ResidenceTime_belt3                0.780986            0.757221
# Temp_exhaust_in                   -0.101718           -0.100120
# Temp_exhaust_out                  -0.639194           -0.624652
# Temp_product_in                    0.751952            0.730798
# Temp_product_out                  -0.712028           -0.692089
# Temp_tunnel_measured              -0.769669           -0.749663
# Temp_tunnel_set                   -0.750279           -0.726763
# Vanne_opening_rate                 0.418356            0.409712
#
#                          FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# BeltAmpere_belt1               0.975562       0.975524           0.565859
# BeltAmpere_belt2               0.985276       0.985264           0.559215
# BeltAmpere_belt3               0.985797       0.985822           0.559335
# Cumulative_LIN_flow            0.007556       0.010758          -0.062220
# Cumulative_product_flow        0.047621       0.050885          -0.044007
# FanAmpere_exhaust1             0.760235       0.760651           0.920998
# FanAmpere_exhaust2             0.736020       0.736699           0.942922
# FanAmpere_side                 1.000000       0.999950           0.531989
# FanAmpere_top                  0.999950       1.000000           0.533107
# Fanspeed_exhaust1              0.531989       0.533107           1.000000
# Fanspeed_exhaust2              0.736410       0.736992           0.952120
# Fanspeed_side                  0.999998       0.999958           0.531985
# Fanspeed_top                   0.999998       0.999958           0.531985
# LIN_flow                       0.728034       0.732453           0.454623
# Product_flow                   0.849720       0.850229           0.456186
# ResidenceTime_belt1            0.985456       0.985421           0.561248
# ResidenceTime_belt2            0.985456       0.985421           0.561248
# ResidenceTime_belt3            0.985456       0.985421           0.561248
# Temp_exhaust_in               -0.172633      -0.176022          -0.002101
# Temp_exhaust_out              -0.789777      -0.789677          -0.494667
# Temp_product_in                0.947965       0.947851           0.552860
# Temp_product_out              -0.890151      -0.891232          -0.502519
# Temp_tunnel_measured          -0.946918      -0.947332          -0.555231
# Temp_tunnel_set               -0.989083      -0.989707          -0.517386
# Vanne_opening_rate             0.539074       0.543582           0.307267
#
#                          ...  ResidenceTime_belt1  ResidenceTime_belt2  \
# BeltAmpere_belt1         ...             0.997890             0.997890
# BeltAmpere_belt2         ...             0.999838             0.999838
# BeltAmpere_belt3         ...             0.999699             0.999699
# Cumulative_LIN_flow      ...             0.001252             0.001252
# Cumulative_product_flow  ...             0.042081             0.042081
# FanAmpere_exhaust1       ...             0.780986             0.780986
# FanAmpere_exhaust2       ...             0.757221             0.757221
# FanAmpere_side           ...             0.985456             0.985456
# FanAmpere_top            ...             0.985421             0.985421
# Fanspeed_exhaust1        ...             0.561248             0.561248
# Fanspeed_exhaust2        ...             0.758740             0.758740
# Fanspeed_side            ...             0.985432             0.985432
# Fanspeed_top             ...             0.985432             0.985432
# LIN_flow                 ...             0.727169             0.727169
# Product_flow             ...             0.855150             0.855150
# ResidenceTime_belt1      ...             1.000000             1.000000
# ResidenceTime_belt2      ...             1.000000             1.000000
# ResidenceTime_belt3      ...             1.000000             1.000000
# Temp_exhaust_in          ...            -0.168210            -0.168210
# Temp_exhaust_out         ...            -0.801533            -0.801533
# Temp_product_in          ...             0.961902             0.961902
# Temp_product_out         ...            -0.901452            -0.901452
# Temp_tunnel_measured     ...            -0.959574            -0.959574
# Temp_tunnel_set          ...            -0.974717            -0.974717
# Vanne_opening_rate       ...             0.531383             0.531383
#
#                          ResidenceTime_belt3  Temp_exhaust_in  \
# BeltAmpere_belt1                    0.997890        -0.165877
# BeltAmpere_belt2                    0.999838        -0.179757
# BeltAmpere_belt3                    0.999699        -0.180713
# Cumulative_LIN_flow                 0.001252        -0.711118
# Cumulative_product_flow             0.042081        -0.739314
# FanAmpere_exhaust1                  0.780986        -0.101718
# FanAmpere_exhaust2                  0.757221        -0.100120
# FanAmpere_side                      0.985456        -0.172633
# FanAmpere_top                       0.985421        -0.176022
# Fanspeed_exhaust1                   0.561248        -0.002101
# Fanspeed_exhaust2                   0.758740        -0.072896
# Fanspeed_side                       0.985432        -0.172953
# Fanspeed_top                        0.985432        -0.172953
# LIN_flow                            0.727169        -0.351995
# Product_flow                        0.855150        -0.340000
# ResidenceTime_belt1                 1.000000        -0.168210
# ResidenceTime_belt2                 1.000000        -0.168210
# ResidenceTime_belt3                 1.000000        -0.168210
# Temp_exhaust_in                    -0.168210         1.000000
# Temp_exhaust_out                   -0.801533        -0.115974
# Temp_product_in                     0.961902        -0.103474
# Temp_product_out                   -0.901452         0.387502
# Temp_tunnel_measured               -0.959574         0.268447
# Temp_tunnel_set                    -0.974717         0.279201
# Vanne_opening_rate                  0.531383        -0.303300
#
#                          Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# BeltAmpere_belt1                -0.799874         0.958910         -0.898913
# BeltAmpere_belt2                -0.797299         0.961290         -0.902665
# BeltAmpere_belt3                -0.798935         0.962122         -0.902923
# Cumulative_LIN_flow              0.298358        -0.099483         -0.209191
# Cumulative_product_flow          0.263194        -0.055860         -0.249632
# FanAmpere_exhaust1              -0.639194         0.751952         -0.712028
# FanAmpere_exhaust2              -0.624652         0.730798         -0.692089
# FanAmpere_side                  -0.789777         0.947965         -0.890151
# FanAmpere_top                   -0.789677         0.947851         -0.891232
# Fanspeed_exhaust1               -0.494667         0.552860         -0.502519
# Fanspeed_exhaust2               -0.634429         0.734934         -0.688225
# Fanspeed_side                   -0.789878         0.948050         -0.890204
# Fanspeed_top                    -0.789878         0.948050         -0.890204
# LIN_flow                        -0.679460         0.782090         -0.694243
# Product_flow                    -0.674506         0.876609         -0.798502
# ResidenceTime_belt1             -0.801533         0.961902         -0.901452
# ResidenceTime_belt2             -0.801533         0.961902         -0.901452
# ResidenceTime_belt3             -0.801533         0.961902         -0.901452
# Temp_exhaust_in                 -0.115974        -0.103474          0.387502
# Temp_exhaust_out                 1.000000        -0.843004          0.706966
# Temp_product_in                 -0.843004         1.000000         -0.861515
# Temp_product_out                 0.706966        -0.861515          1.000000
# Temp_tunnel_measured             0.809422        -0.915835          0.919220
# Temp_tunnel_set                  0.754985        -0.929359          0.912661
# Vanne_opening_rate              -0.249110         0.486832         -0.531000
#
#                          Temp_tunnel_measured  Temp_tunnel_set  \
# BeltAmpere_belt1                    -0.957182        -0.964891
# BeltAmpere_belt2                    -0.960430        -0.975595
# BeltAmpere_belt3                    -0.960746        -0.976474
# Cumulative_LIN_flow                 -0.106195        -0.120031
# Cumulative_product_flow             -0.149214        -0.161396
# FanAmpere_exhaust1                  -0.769669        -0.750279
# FanAmpere_exhaust2                  -0.749663        -0.726763
# FanAmpere_side                      -0.946918        -0.989083
# FanAmpere_top                       -0.947332        -0.989707
# Fanspeed_exhaust1                   -0.555231        -0.517386
# Fanspeed_exhaust2                   -0.747673        -0.723639
# Fanspeed_side                       -0.946837        -0.989127
# Fanspeed_top                        -0.946837        -0.989127
# LIN_flow                            -0.718593        -0.763471
# Product_flow                        -0.834233        -0.854376
# ResidenceTime_belt1                 -0.959574        -0.974717
# ResidenceTime_belt2                 -0.959574        -0.974717
# ResidenceTime_belt3                 -0.959574        -0.974717
# Temp_exhaust_in                      0.268447         0.279201
# Temp_exhaust_out                     0.809422         0.754985
# Temp_product_in                     -0.915835        -0.929359
# Temp_product_out                     0.919220         0.912661
# Temp_tunnel_measured                 1.000000         0.957719
# Temp_tunnel_set                      0.957719         1.000000
# Vanne_opening_rate                  -0.512063        -0.567696
#
#                          Vanne_opening_rate
# BeltAmpere_belt1                   0.526536
# BeltAmpere_belt2                   0.533900
# BeltAmpere_belt3                   0.533048
# Cumulative_LIN_flow                0.242928
# Cumulative_product_flow            0.269498
# FanAmpere_exhaust1                 0.418356
# FanAmpere_exhaust2                 0.409712
# FanAmpere_side                     0.539074
# FanAmpere_top                      0.543582
# Fanspeed_exhaust1                  0.307267
# Fanspeed_exhaust2                  0.408025
# Fanspeed_side                      0.539239
# Fanspeed_top                       0.539239
# LIN_flow                           0.471273
# Product_flow                       0.542082
# ResidenceTime_belt1                0.531383
# ResidenceTime_belt2                0.531383
# ResidenceTime_belt3                0.531383
# Temp_exhaust_in                   -0.303300
# Temp_exhaust_out                  -0.249110
# Temp_product_in                    0.486832
# Temp_product_out                  -0.531000
# Temp_tunnel_measured              -0.512063
# Temp_tunnel_set                   -0.567696
# Vanne_opening_rate                 1.000000
#
# [25 rows x 25 columns]
#
#
# (445, 26)

# %%
corr_ = x.corrwith(y, method='spearman')
sa = dict(corr_).items()
sorted(sa, key = lambda x : x[1])
# Out:
# [('Temp_tunnel_set', -0.6971561386741886),
#  ('Temp_tunnel_measured', -0.670263378544298),
#  ('Temp_exhaust_out', -0.5707549690798337),
#  ('Temp_product_out', -0.4696465896350307),
#  ('Cumulative_product_flow', -0.29640631312571447),
#  ('Cumulative_LIN_flow', -0.29043603466641565),
#  ('Temp_exhaust_in', -0.23187678366605166),
#  ('FanAmpere_side', 0.2365154119374328),
#  ('BeltAmpere_belt1', 0.32447380387671815),
#  ('Fanspeed_exhaust1', 0.42805721288279097),
#  ('Fanspeed_exhaust2', 0.42805721288279097),
#  ('FanAmpere_exhaust1', 0.48105371753913473),
#  ('Vanne_opening_rate', 0.48202627979972695),
#  ('FanAmpere_exhaust2', 0.5101916385569909),
#  ('BeltAmpere_belt2', 0.5361235673714928),
#  ('Product_flow', 0.5948856046049577),
#  ('BeltAmpere_belt3', 0.6483795750042661),
#  ('ResidenceTime_belt1', 0.6490323290542469),
#  ('ResidenceTime_belt2', 0.6490323290542469),
#  ('ResidenceTime_belt3', 0.6490323290542469),
#  ('Fanspeed_side', 0.6542555475424316),
#  ('Fanspeed_top', 0.6542555475424316),
#  ('Temp_product_in', 0.6703966886709504),
#  ('FanAmpere_top', 0.7361636267191842),
#  ('LIN_flow', 1.0)]

# %%
x[['Temp_exhaust_out', 'Temp_product_in', 'Temp_tunnel_set', 'Temp_exhaust_in', 'BeltAmpere_belt2', 'LIN_flow']].corr()
# Out:
#                   Temp_exhaust_out  Temp_product_in  Temp_tunnel_set  \
# Temp_exhaust_out          1.000000        -0.843004         0.754985
# Temp_product_in          -0.843004         1.000000        -0.929359
# Temp_tunnel_set           0.754985        -0.929359         1.000000
# Temp_exhaust_in          -0.115974        -0.103474         0.279201
# BeltAmpere_belt2         -0.797299         0.961290        -0.975595
# LIN_flow                 -0.679460         0.782090        -0.763471
#
#                   Temp_exhaust_in  BeltAmpere_belt2  LIN_flow
# Temp_exhaust_out        -0.115974         -0.797299 -0.679460
# Temp_product_in         -0.103474          0.961290  0.782090
# Temp_tunnel_set          0.279201         -0.975595 -0.763471
# Temp_exhaust_in          1.000000         -0.179757 -0.351995
# BeltAmpere_belt2        -0.179757          1.000000  0.728934
# LIN_flow                -0.351995          0.728934  1.000000

# %%
plt.figure(figsize=(25, 25))
sns.heatmap(x[::].corr(), square=True, annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(nrows=9, ncols=3, figsize=(20, 65))
colormap = ["red", "green", "blue"]
for idx, feature in enumerate(x.columns[:-1]):
    x.plot(feature, "LIN_flow", subplots=True, kind="scatter", 
           ax=axes[idx // 3, idx % 3], color=colormap[idx % 3], grid=True)

# %%
x.hist(figsize=(20, 35), bins=100);

# %%
x.mean()
# Out:
# BeltAmpere_belt1              1.974509
# BeltAmpere_belt2              2.915167
# BeltAmpere_belt3              2.859957
# Cumulative_LIN_flow        7190.874157
# Cumulative_product_flow    8401.123596
# FanAmpere_exhaust1            1.868738
# FanAmpere_exhaust2            2.146780
# FanAmpere_side                6.480585
# FanAmpere_top                 6.576487
# Fanspeed_exhaust1            47.303371
# Fanspeed_exhaust2            62.269663
# Fanspeed_side                32.359551
# Fanspeed_top                 56.629213
# LIN_flow                    878.368544
# Product_flow                863.953002
# ResidenceTime_belt1          65.078652
# ResidenceTime_belt2         122.022472
# ResidenceTime_belt3         122.022472
# Temp_exhaust_in               6.777753
# Temp_exhaust_out              3.399775
# Temp_product_in              17.698678
# Temp_product_out            -21.872423
# Temp_tunnel_measured        -60.600449
# Temp_tunnel_set             -59.696629
# Vanne_opening_rate           17.626396
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler, scale
from sklearn.utils import shuffle
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x.iloc[:, :-1])

# %%
x_scaled = pd.DataFrame(x_scaled, columns=named_cols)
x_scaled.hist(figsize=(20, 35), bins=100);

# %%
x_scaled
# Out:
#      BeltAmpere_belt1  BeltAmpere_belt2  BeltAmpere_belt3  \
# 0           -2.086270         -2.089549         -2.089433
# 1           -2.086270         -2.089549         -2.089433
# 2            0.481716          0.495586          0.513355
# 3            0.478492          0.485086          0.515584
# 4            0.479136          0.482461          0.493735
# ..                ...               ...               ...
# 440         -2.086270         -2.089549         -2.089433
# 441         -2.086270         -2.089549         -2.089433
# 442         -2.086270         -2.089549         -2.089433
# 443         -2.086270         -2.089549         -2.089433
# 444         -2.086270         -2.089549         -2.089433
#
#      Cumulative_LIN_flow  Cumulative_product_flow  FanAmpere_exhaust1  \
# 0               2.096301                 2.147103           -2.285484
# 1               2.097837                 2.147103           -2.285484
# 2               2.100211                 2.147650            0.346304
# 3               2.101747                 2.149183            0.353776
# 4               2.104121                 2.152028            0.363383
# ..                   ...                      ...                 ...
# 440            -0.004172                -0.143067            1.391867
# 441            -0.003055                -0.143067            1.364647
# 442            -0.001938                -0.143067            1.376922
# 443            -0.000681                -0.143067            1.383861
# 444             0.000437                -0.143067            1.386529
#
#      FanAmpere_exhaust2  FanAmpere_side  FanAmpere_top  Fanspeed_exhaust1  \
# 0             -2.248478       -2.058296      -2.058215          -1.896781
# 1             -2.248478       -2.058296      -2.058215          -1.896781
# 2              0.322110        0.486758       0.513237           0.108130
# 3              0.318911        0.489812       0.485730           0.108130
# 4              0.325310        0.487631       0.507649           0.108130
# ..                  ...             ...            ...                ...
# 440            1.445143       -2.058296      -2.058215           2.113041
# 441            1.492222       -2.058296      -2.058215           2.113041
# 442            1.452913       -2.058296      -2.058215           2.113041
# 443            1.438744       -2.058296      -2.058215           2.113041
# 444            1.180953       -2.058296      -2.058215           2.113041
#
#      ...  ResidenceTime_belt1  ResidenceTime_belt2  ResidenceTime_belt3  \
# 0    ...            -2.088407            -2.088407            -2.088407
# 1    ...            -2.088407            -2.088407            -2.088407
# 2    ...             0.478834             0.478834             0.478834
# 3    ...             0.478834             0.478834             0.478834
# 4    ...             0.478834             0.478834             0.478834
# ..   ...                  ...                  ...                  ...
# 440  ...            -2.088407            -2.088407            -2.088407
# 441  ...            -2.088407            -2.088407            -2.088407
# 442  ...            -2.088407            -2.088407            -2.088407
# 443  ...            -2.088407            -2.088407            -2.088407
# 444  ...            -2.088407            -2.088407            -2.088407
#
#      Temp_exhaust_in  Temp_exhaust_out  Temp_product_in  Temp_product_out  \
# 0          -2.192972          1.131651        -0.444964         -0.716261
# 1          -2.444753          1.216520        -0.438440         -0.827445
# 2          -2.109046          1.103361        -0.424706         -0.675766
# 3          -2.486716          1.075072        -0.396768         -0.752396
# 4          -2.137021          1.131651        -0.289020         -0.843571
# ..               ...               ...              ...               ...
# 440         0.520660          2.008631        -2.047537          2.016686
# 441         0.534648          2.206659        -2.047537          2.016686
# 442         0.548636          2.234949        -2.047537          2.016686
# 443         0.562624          2.291528        -2.047537          2.016686
# 444         0.576612          2.093500        -2.047537          2.016686
#
#      Temp_tunnel_measured  Temp_tunnel_set  Vanne_opening_rate
# 0                2.084504         2.035606           -1.109745
# 1                2.084504         2.035606           -1.109745
# 2               -0.632899        -0.760527            3.184340
# 3               -0.839284        -0.760527           -0.836811
# 4               -0.632899        -0.760527            3.209582
# ..                    ...              ...                 ...
# 440              2.380323         2.035606           -1.109745
# 441              2.387202         2.035606           -1.109745
# 442              2.390642         2.035606           -1.109745
# 443              2.394082         2.035606           -1.109745
# 444              2.397522         2.035606           -1.109745
#
# [445 rows x 25 columns]

# %%
plt.figure(figsize=(20, 55))
for i, feature in enumerate(x_scaled.columns):
    plt.subplot(9, 3, i+1)
    sns.kdeplot(x[feature])
    plt.xlabel(feature)
plt.show()

# %%
x.drop(["Cumulative_LIN_flow","Cumulative_product_flow"], 1,inplace=True)
df_shuffled = shuffle(x, random_state=123)
X = df_shuffled[df_shuffled.columns[:-1]]
X = scale(df_shuffled.drop(["LIN_flow", "_time"], 1))
y = df_shuffled["LIN_flow"]

df_shuffled = df_shuffled.drop(["LIN_flow"], 1)
print(X)
print('\n')
print(y)
# Out:
# [[ 0.48494048  0.46539917  0.48437055 ... -0.30956211 -0.3513365
#    0.2585626 ]
#  [ 0.46688326  0.4745865   0.50176118 ... -0.56066392 -0.48773322
#   -1.1097447 ]
#  [-2.08369012 -2.08779936 -2.08764937 ...  2.30808822  2.03560613
#   -1.1097447 ]
#  ...
#  [ 0.47268739  0.47196156  0.47099323 ... -0.23732734 -0.28313814
#    0.73145824]
#  [-2.08369012 -2.08779936 -2.08764937 ...  1.7370896   2.03560613
#   -1.1097447 ]
#  [-2.08369012 -2.08779936 -2.08764937 ... -0.0447013   2.03560613
#   -1.1097447 ]]
#
#
# 281    1042.34360
# 162    1076.36910
# 422     465.61920
# 131     978.78490
# 138     939.04780
#           ...
# 230     862.58704
# 98      969.94330
# 322     779.67340
# 382     370.42578
# 365     101.53061
# Name: LIN_flow, Length: 445, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
regr = LinearRegression()
regr.fit(X, y)
print('Коэффициенты: ')
list(zip(df_shuffled.columns, regr.coef_))
# Out:
# Коэффициенты:
# [('BeltAmpere_belt1', 86.96305659861328),
#  ('BeltAmpere_belt2', 111.84304332679034),
#  ('BeltAmpere_belt3', -363.2635372997311),
#  ('FanAmpere_exhaust1', -170.39185550556144),
#  ('FanAmpere_exhaust2', 153.55458890558228),
#  ('FanAmpere_side', -4971.954575277168),
#  ('FanAmpere_top', 13420.229452262995),
#  ('Fanspeed_exhaust1', -35.3631639555517),
#  ('Fanspeed_exhaust2', 69.87565224112107),
#  ('Fanspeed_side', -4434.814894362821),
#  ('Fanspeed_top', -4434.81489436278),
#  ('Product_flow', 81.35977304590465),
#  ('ResidenceTime_belt1', 31.412041059533365),
#  ('ResidenceTime_belt2', 31.412041059539703),
#  ('ResidenceTime_belt3', 31.4120410595297),
#  ('Temp_exhaust_in', -50.611378965648484),
#  ('Temp_exhaust_out', -103.67543489635628),
#  ('Temp_product_in', 272.8265934093907),
#  ('Temp_product_out', 99.29687371341825),
#  ('Temp_tunnel_measured', 213.64725113658258),
#  ('Temp_tunnel_set', -613.879600066241),
#  ('Vanne_opening_rate', -61.54209605684437)]

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
regLasso = Lasso()
regLasso.fit(X, y)
print('Коэффициенты:')
list(zip(df_shuffled.columns, regLasso.coef_))
# Out:
# Коэффициенты:
# [('BeltAmpere_belt1', -0.0),
#  ('BeltAmpere_belt2', -3.2628936381013154),
#  ('BeltAmpere_belt3', -0.0),
#  ('FanAmpere_exhaust1', -74.86042183832333),
#  ('FanAmpere_exhaust2', 0.0),
#  ('FanAmpere_side', -566.8389336960364),
#  ('FanAmpere_top', -0.0),
#  ('Fanspeed_exhaust1', 88.6064993940186),
#  ('Fanspeed_exhaust2', -0.0),
#  ('Fanspeed_side', -0.0),
#  ('Fanspeed_top', -0.0),
#  ('Product_flow', 56.14837845013617),
#  ('ResidenceTime_belt1', -0.0),
#  ('ResidenceTime_belt2', -0.0),
#  ('ResidenceTime_belt3', -0.0),
#  ('Temp_exhaust_in', -89.92864704363795),
#  ('Temp_exhaust_out', -179.73896225573506),
#  ('Temp_product_in', 213.80251466208253),
#  ('Temp_product_out', 86.83345963378407),
#  ('Temp_tunnel_measured', 252.95547853760888),
#  ('Temp_tunnel_set', -711.5220772840041),
#  ('Vanne_opening_rate', 21.57740803931023)]

# %%
regRidge = Ridge()
regRidge.fit(X, y)
print('Коэффициенты: ')
list(zip(df_shuffled.columns, regRidge.coef_))
# Out:
# Коэффициенты:
# [('BeltAmpere_belt1', 39.47636981026297),
#  ('BeltAmpere_belt2', -49.737675128369),
#  ('BeltAmpere_belt3', 24.199255153715672),
#  ('FanAmpere_exhaust1', -177.28721124650664),
#  ('FanAmpere_exhaust2', 239.5329864924662),
#  ('FanAmpere_side', -208.78103541248655),
#  ('FanAmpere_top', 58.20951585616906),
#  ('Fanspeed_exhaust1', 109.10783528926136),
#  ('Fanspeed_exhaust2', -166.912369363089),
#  ('Fanspeed_side', -185.14370152670773),
#  ('Fanspeed_top', -185.14370152676153),
#  ('Product_flow', 59.36983824968098),
#  ('ResidenceTime_belt1', -16.599983146730928),
#  ('ResidenceTime_belt2', -16.59998314673904),
#  ('ResidenceTime_belt3', -16.5999831467254),
#  ('Temp_exhaust_in', -89.1778940368401),
#  ('Temp_exhaust_out', -179.56949246249488),
#  ('Temp_product_in', 229.25441830191866),
#  ('Temp_product_out', 88.06782623488807),
#  ('Temp_tunnel_measured', 245.6583744808212),
#  ('Temp_tunnel_set', -686.7993265596504),
#  ('Vanne_opening_rate', 23.598682492776664)]

# %%
# Код 3.1 (1 балл)
alphas = np.arange(1, 500, 50)
coefs_lasso = np.zeros((alphas.shape[0], X.shape[1])) # матрица весов размера (число регрессоров) x (число признаков)
coefs_ridge = np.zeros((alphas.shape[0], X.shape[1]))
# Для каждого значения коэффициента из alphas обучите регрессор Lasso
# и запишите веса в соответствующую строку матрицы coefs_lasso (вспомните встроенную в python функцию enumerate),
# а затем обучите Ridge и запишите веса в coefs_ridge.

for i, item in enumerate(alphas):
    reg_Lasso = Lasso(alpha = alphas[i])
    reg_Lasso.fit(X, y)
    coefs_lasso[i,:] = reg_Lasso.coef_

for i, item in enumerate(alphas):
    reg_Ridge = Ridge(alpha = alphas[i])
    reg_Ridge.fit(X, y)
    coefs_ridge[i,:] = reg_Ridge.coef_

# %%
plt.figure(figsize=(8, 5))

for coef, feature in zip(coefs_lasso.T, df_shuffled.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))
    
plt.legend(loc="upper right", bbox_to_anchor=(1.6, 1))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Lasso")

plt.figure(figsize=(8, 5))

for coef, feature in zip(coefs_ridge.T, df_shuffled.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))
    
plt.legend(loc="upper right", bbox_to_anchor=(1.6, 1))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Ridge")
# Out:
# Text(0.5, 1.0, 'Ridge')

# %%
from sklearn.linear_model import LassoCV

# %%
# Код 3.2 (1 балл)
# Обучите регрессор LassoCV на всех параметрах регуляризации из alpha
# Постройте график _усредненного_ по строкам MSE в зависимости от alpha. 
# Выведите выбранное alpha, а также пары "признак-коэффициент" для обученного вектора коэффициентов

alphas = np.arange(1, 100, 5)
regLassoCV = LassoCV(alphas=alphas)
regLassoCV.fit(X, y)
print('Матрица переменной mse_path_: \n', regLassoCV.mse_path_)

plt.plot(regLassoCV.alphas_, regLassoCV.mse_path_.mean(axis=1))
plt.xlabel('alphas')
plt.ylabel('MSE')
plt.show()

print('Выбранное alpha:', regLassoCV.alpha_, '\n')
print('Вектор коэффициентов для выбранного alpha:')
list(zip(df_shuffled.columns, regLassoCV.coef_))
# Out:
# Матрица переменной mse_path_:
#  [[41102.41952468 42703.03196931 48868.97833465 38598.10010115
#   49733.54127242]
#  [40008.45068035 41534.25882974 47521.18866374 38020.68864055
#   48739.53589119]
#  [38960.46574093 40419.79130534 46193.24193291 37480.26338247
#   47801.81977051]
#  [37980.56579371 39359.13989653 44928.62685699 36976.67170682
#   46920.1983517 ]
#  [37068.70084872 38298.27234141 43727.53971162 36434.83252801
#   46071.48544677]
#  [36224.71846013 37250.44490583 42589.97967396 35917.69532069
#   45171.13861726]
#  [35175.01030515 36266.82599415 41424.01082954 35444.60115942
#   44338.99410068]
#  [33907.11503491 34809.30509561 39743.33604719 35015.35373866
#   42974.18026653]
#  [32779.75568644 33176.48904571 37956.25378821 33711.13884393
#   41541.75373251]
#  [31953.97396904 31666.21578201 36284.46107674 32493.20427102
#   40257.39022375]
#  [31311.28676673 30278.52667223 34734.13003343 31367.93967952
#   39121.40379634]
#  [30804.93904427 29013.40232918 33305.78839853 30335.1635073
#   38133.51199625]
#  [30434.62208585 27870.85282423 31999.55885058 29406.24443321
#   37348.1051335 ]
#  [30200.82704744 26850.86422201 30815.44160761 28657.95454242
#   36724.09361527]
#  [30101.17795843 25953.43584304 29753.43241633 28014.86819005
#   36230.64371253]
#  [30142.17260533 25234.0113105  28813.45836949 27474.50340413
#   35868.13314215]
#  [30367.10719029 24474.0065123  27711.05623665 27032.86107178
#   35416.03860491]
#  [30775.28913964 23776.39123211 26688.97242157 26666.28534318
#   35009.31935827]
#  [27553.84038029 19399.56924699 25849.98272415 23721.13539647
#   31022.29540833]
#  [17460.13816313 11384.54556138 16684.57984272 16146.27364353
#   17121.21533945]]
# Выбранное alpha: 1
#
# Вектор коэффициентов для выбранного alpha:
# [('BeltAmpere_belt1', -0.0),
#  ('BeltAmpere_belt2', -3.2628936381013154),
#  ('BeltAmpere_belt3', -0.0),
#  ('FanAmpere_exhaust1', -74.86042183832333),
#  ('FanAmpere_exhaust2', 0.0),
#  ('FanAmpere_side', -566.8389336960364),
#  ('FanAmpere_top', -0.0),
#  ('Fanspeed_exhaust1', 88.6064993940186),
#  ('Fanspeed_exhaust2', -0.0),
#  ('Fanspeed_side', -0.0),
#  ('Fanspeed_top', -0.0),
#  ('Product_flow', 56.14837845013617),
#  ('ResidenceTime_belt1', -0.0),
#  ('ResidenceTime_belt2', -0.0),
#  ('ResidenceTime_belt3', -0.0),
#  ('Temp_exhaust_in', -89.92864704363795),
#  ('Temp_exhaust_out', -179.73896225573506),
#  ('Temp_product_in', 213.80251466208253),
#  ('Temp_product_out', 86.83345963378407),
#  ('Temp_tunnel_measured', 252.95547853760888),
#  ('Temp_tunnel_set', -711.5220772840041),
#  ('Vanne_opening_rate', 21.57740803931023)]

# %%
min_alphas = []
for i in range(3):
    z = dict(zip(regLassoCV.alphas_, regLassoCV.mse_path_[:, i]))
    min_alphas.append(sorted(z, key=z.get)[0])
    plt.figure(figsize=(8, 5))
    plt.plot(regLassoCV.alphas_, regLassoCV.mse_path_[:, i], label='mse{} from alpha'.format(i))
    plt.legend(loc='best')
    plt.xlabel('alpha')
    plt.ylabel('mse')

min_alphas
# Out:
# [1, 1, 1]
